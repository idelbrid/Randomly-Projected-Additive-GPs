# %% [markdown]
# # Introduction
# As described in the repo README, the experiment runner provides the fixture for running experiments on UCI data sets. One can also use this repo as a module providing an API to the RPA-GP family of GP models.
#
# Below are demonstrations on how to create and use these models on example data.

# %%
# Preliminary imports
import torch
from torch.optim import Adam
from gpytorch.kernels import RBFKernel, ScaleKernel, AdditiveStructureKernel
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.mlls import ExactMarginalLogLikelihood
# Out:
# 7.4.0

# %%
from gp_experiment_runner import _determine_folds, _access_fold, _normalize_by_train

# %%
# Load a data set
from gp_experiment_runner import load_dataset  # assumes UCI datasets are available locally
dataset = load_dataset('yacht') # returns a Pandas dataframe

n_train = len(dataset) // 10 * 9
train = dataset.iloc[:n_train]
test = dataset.iloc[n_train:]

# Or use utilities from repo:
# from gp_experiment_runner import _determine_folds, _access_fold, _normalize_by_train
# folds = _determine_folds(0.1, dataset)
# train, test = _access_fold(dataset, folds, 0)
# train, test = _normalize_by_train(train, test)

train_x = torch.tensor(train.iloc[:, :-1].values, dtype=torch.float)
train_y = torch.tensor(train.iloc[:, -1].values, dtype=torch.float)
test_x = torch.tensor(test.iloc[:, :-1].values, dtype=torch.float)
test_y = torch.tensor(test.iloc[:, -1].values, dtype=torch.float)

# %% [markdown]
# ### Create an RPA-GP model

# %%
from gp_models import ExactGPModel, ScaledProjectionKernel
import rp
n, d = train_x.shape
num_projs = 20

# Draw random projections and store in a linear module
# Here, we are drawing 20 Gaussian projections into 1 dimension.
projs = [rp.gen_rp(d, 1, dist='gaussian') for _ in range(num_projs)]
proj_module = torch.nn.Linear(d, num_projs, bias=False)
proj_module.weight.data = torch.cat(projs, dim=1).t()

# Create the additive model that operates over these projections
# Fixing the outputscale and lengthscale of the base kernels.
base_kernel = RBFKernel()
base_kernel.initialize(lengthscale=torch.tensor([1.]))
base_kernel = ScaleKernel(base_kernel)
base_kernel.initialize(outputscale=torch.tensor([1/num_projs]))

# Combine into a single module.
kernel = ScaledProjectionKernel(proj_module, base_kernel, 
                                prescale=False,
                                ard_num_dims=num_projs,
                                learn_proj=False)
# Or, just call the method from training_routines that wraps this initialization
# from training_routines import create_additive_rp_kernel
# create_additive_rp_kernel(d, num_projs, learn_proj=False, kernel_type='RBF', 
#                           space_proj=False, prescale=False, ard=True, k=1, 
#                           proj_dist='gaussian')

kernel = ScaleKernel(kernel) # Optionally wrap with an additional ScaleKernel 

# Create an ExactGP model with this kernel
likelihood = GaussianLikelihood()
likelihood.noise = 1.
model = ExactGPModel(train_x, train_y, likelihood, kernel)

# %% [markdown]
# ### Train the model

# %%
# Train the model
mll = ExactMarginalLogLikelihood(model.likelihood, model)
mll.train()
optimizer = Adam(mll.parameters(), lr=0.01)
for iteration in range(1000):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()
    msg = "Iter {}: Loss={:2.4f}, Noise={:2.4f}".format(iteration, loss.item(), model.likelihood.noise.item())
    print(msg)
# Out:
# Iter 0: Loss=1.4288, Noise=0.9937
# Iter 1: Loss=1.4287, Noise=0.9893
# Iter 2: Loss=1.4288, Noise=0.9862
# Iter 3: Loss=1.4290, Noise=0.9824
# Iter 4: Loss=1.4288, Noise=0.9824
# Iter 5: Loss=1.4289, Noise=0.9836
# Iter 6: Loss=1.4286, Noise=0.9857
# Iter 7: Loss=1.4286, Noise=0.9879
# Iter 8: Loss=1.4285, Noise=0.9907
# Iter 9: Loss=1.4286, Noise=0.9941
# Iter 10: Loss=1.4288, Noise=0.9972
# Iter 11: Loss=1.4286, Noise=0.9992
# Iter 12: Loss=1.4287, Noise=0.9998
# Iter 13: Loss=1.4288, Noise=0.9990
# Iter 14: Loss=1.4287, Noise=0.9976
# Iter 15: Loss=1.4287, Noise=0.9952
# Iter 16: Loss=1.4288, Noise=0.9918
# Iter 17: Loss=1.4288, Noise=0.9883
# Iter 18: Loss=1.4288, Noise=0.9851
# Iter 19: Loss=1.4287, Noise=0.9811
# Iter 20: Loss=1.4286, Noise=0.9770
# Iter 21: Loss=1.4289, Noise=0.9738
# Iter 22: Loss=1.4286, Noise=0.9699
# Iter 23: Loss=1.4287, Noise=0.9671
# Iter 24: Loss=1.4288, Noise=0.9654
# Iter 25: Loss=1.4288, Noise=0.9635
# Iter 26: Loss=1.4289, Noise=0.9611
# Iter 27: Loss=1.4289, Noise=0.9600
# Iter 28: Loss=1.4289, Noise=0.9592
# Iter 29: Loss=1.4288, Noise=0.9593
# Iter 30: Loss=1.4288, Noise=0.9602
# Iter 31: Loss=1.4287, Noise=0.9617
# Iter 32: Loss=1.4287, Noise=0.9636
# Iter 33: Loss=1.4290, Noise=0.9652
# Iter 34: Loss=1.4288, Noise=0.9674
# Iter 35: Loss=1.4286, Noise=0.9697
# Iter 36: Loss=1.4287, Noise=0.9730
# Iter 37: Loss=1.4288, Noise=0.9771
# Iter 38: Loss=1.4288, Noise=0.9818
# Iter 39: Loss=1.4287, Noise=0.9862
# Iter 40: Loss=1.4285, Noise=0.9897
# Iter 41: Loss=1.4287, Noise=0.9940
# Iter 42: Loss=1.4288, Noise=0.9976
# Iter 43: Loss=1.4287, Noise=1.0002
# Iter 44: Loss=1.4287, Noise=1.0009
# Iter 45: Loss=1.4287, Noise=1.0006
# Iter 46: Loss=1.4288, Noise=0.9999
# Iter 47: Loss=1.4285, Noise=0.9990
# Iter 48: Loss=1.4288, Noise=0.9976
# Iter 49: Loss=1.4288, Noise=0.9966
# Iter 50: Loss=1.4288, Noise=0.9957
# Iter 51: Loss=1.4286, Noise=0.9949
# Iter 52: Loss=1.4287, Noise=0.9937
# Iter 53: Loss=1.4287, Noise=0.9932
# Iter 54: Loss=1.4287, Noise=0.9931
# Iter 55: Loss=1.4289, Noise=0.9931
# Iter 56: Loss=1.4287, Noise=0.9934
# Iter 57: Loss=1.4289, Noise=0.9935
# Iter 58: Loss=1.4288, Noise=0.9935
# Iter 59: Loss=1.4287, Noise=0.9928
# Iter 60: Loss=1.4287, Noise=0.9923
# Iter 61: Loss=1.4285, Noise=0.9914
# Iter 62: Loss=1.4288, Noise=0.9903
# Iter 63: Loss=1.4285, Noise=0.9882
# Iter 64: Loss=1.4286, Noise=0.9869
# Iter 65: Loss=1.4286, Noise=0.9859
# Iter 66: Loss=1.4288, Noise=0.9846
# Iter 67: Loss=1.4288, Noise=0.9843
# Iter 68: Loss=1.4287, Noise=0.9841
# Iter 69: Loss=1.4287, Noise=0.9837
# Iter 70: Loss=1.4284, Noise=0.9839
# Iter 71: Loss=1.4288, Noise=0.9838
# Iter 72: Loss=1.4286, Noise=0.9843
# Iter 73: Loss=1.4286, Noise=0.9844
# Iter 74: Loss=1.4286, Noise=0.9850
# Iter 75: Loss=1.4286, Noise=0.9858
# Iter 76: Loss=1.4287, Noise=0.9864
# Iter 77: Loss=1.4286, Noise=0.9877
# Iter 78: Loss=1.4287, Noise=0.9892
# Iter 79: Loss=1.4287, Noise=0.9906
# Iter 80: Loss=1.4288, Noise=0.9920
# Iter 81: Loss=1.4286, Noise=0.9930
# Iter 82: Loss=1.4285, Noise=0.9937
# Iter 83: Loss=1.4285, Noise=0.9942
# Iter 84: Loss=1.4286, Noise=0.9948
# Iter 85: Loss=1.4288, Noise=0.9958
# Iter 86: Loss=1.4289, Noise=0.9964
# Iter 87: Loss=1.4288, Noise=0.9973
# Iter 88: Loss=1.4288, Noise=0.9974
# Iter 89: Loss=1.4287, Noise=0.9974
# Iter 90: Loss=1.4287, Noise=0.9971
# Iter 91: Loss=1.4288, Noise=0.9970
# Iter 92: Loss=1.4287, Noise=0.9971
# Iter 93: Loss=1.4289, Noise=0.9977
# Iter 94: Loss=1.4286, Noise=0.9976
# Iter 95: Loss=1.4288, Noise=0.9972
# Iter 96: Loss=1.4287, Noise=0.9973
# Iter 97: Loss=1.4287, Noise=0.9971
# Iter 98: Loss=1.4287, Noise=0.9965
# Iter 99: Loss=1.4286, Noise=0.9965
# Iter 100: Loss=1.4287, Noise=0.9967
# Iter 101: Loss=1.4288, Noise=0.9973
# Iter 102: Loss=1.4286, Noise=0.9974
# Iter 103: Loss=1.4288, Noise=0.9981
# Iter 104: Loss=1.4287, Noise=0.9986
# Iter 105: Loss=1.4288, Noise=0.9993
# Iter 106: Loss=1.4286, Noise=0.9993
# Iter 107: Loss=1.4288, Noise=0.9985
# Iter 108: Loss=1.4288, Noise=0.9981
# Iter 109: Loss=1.4289, Noise=0.9976
# Iter 110: Loss=1.4289, Noise=0.9973
# Iter 111: Loss=1.4286, Noise=0.9962
# Iter 112: Loss=1.4286, Noise=0.9947
# Iter 113: Loss=1.4288, Noise=0.9939
# Iter 114: Loss=1.4286, Noise=0.9943
# Iter 115: Loss=1.4287, Noise=0.9941
# Iter 116: Loss=1.4286, Noise=0.9931
# Iter 117: Loss=1.4287, Noise=0.9925
# Iter 118: Loss=1.4287, Noise=0.9916
# Iter 119: Loss=1.4288, Noise=0.9903
# Iter 120: Loss=1.4287, Noise=0.9881
# Iter 121: Loss=1.4285, Noise=0.9859
# Iter 122: Loss=1.4285, Noise=0.9839
# Iter 123: Loss=1.4287, Noise=0.9824
# Iter 124: Loss=1.4289, Noise=0.9812
# Iter 125: Loss=1.4286, Noise=0.9804
# Iter 126: Loss=1.4287, Noise=0.9802
# Iter 127: Loss=1.4289, Noise=0.9800
# Iter 128: Loss=1.4287, Noise=0.9800
# Iter 129: Loss=1.4287, Noise=0.9800
# Iter 130: Loss=1.4287, Noise=0.9789
# Iter 131: Loss=1.4288, Noise=0.9770
# Iter 132: Loss=1.4287, Noise=0.9766
# Iter 133: Loss=1.4287, Noise=0.9766
# Iter 134: Loss=1.4285, Noise=0.9766
# Iter 135: Loss=1.4287, Noise=0.9773
# Iter 136: Loss=1.4286, Noise=0.9778
# Iter 137: Loss=1.4285, Noise=0.9791
# Iter 138: Loss=1.4286, Noise=0.9794
# Iter 139: Loss=1.4286, Noise=0.9790
# Iter 140: Loss=1.4287, Noise=0.9782
# Iter 141: Loss=1.4287, Noise=0.9781
# Iter 142: Loss=1.4287, Noise=0.9789
# Iter 143: Loss=1.4287, Noise=0.9791
# Iter 144: Loss=1.4286, Noise=0.9794
# Iter 145: Loss=1.4286, Noise=0.9797
# Iter 146: Loss=1.4288, Noise=0.9798
# Iter 147: Loss=1.4289, Noise=0.9796
# Iter 148: Loss=1.4286, Noise=0.9804
# Iter 149: Loss=1.4287, Noise=0.9820
# Iter 150: Loss=1.4287, Noise=0.9833
# Iter 151: Loss=1.4287, Noise=0.9851
# Iter 152: Loss=1.4288, Noise=0.9860
# Iter 153: Loss=1.4288, Noise=0.9871
# Iter 154: Loss=1.4286, Noise=0.9877
# Iter 155: Loss=1.4286, Noise=0.9880
# Iter 156: Loss=1.4286, Noise=0.9870
# Iter 157: Loss=1.4286, Noise=0.9848
# Iter 158: Loss=1.4287, Noise=0.9829
# Iter 159: Loss=1.4286, Noise=0.9811
# Iter 160: Loss=1.4287, Noise=0.9791
# Iter 161: Loss=1.4287, Noise=0.9779
# Iter 162: Loss=1.4289, Noise=0.9767
# Iter 163: Loss=1.4289, Noise=0.9757
# Iter 164: Loss=1.4289, Noise=0.9742
# Iter 165: Loss=1.4287, Noise=0.9739
# Iter 166: Loss=1.4288, Noise=0.9740
# Iter 167: Loss=1.4287, Noise=0.9747
# Iter 168: Loss=1.4286, Noise=0.9745
# Iter 169: Loss=1.4288, Noise=0.9745
# Iter 170: Loss=1.4288, Noise=0.9744
# Iter 171: Loss=1.4286, Noise=0.9754
# Iter 172: Loss=1.4289, Noise=0.9759
# Iter 173: Loss=1.4287, Noise=0.9764
# Iter 174: Loss=1.4289, Noise=0.9762
# Iter 175: Loss=1.4286, Noise=0.9761
# Iter 176: Loss=1.4288, Noise=0.9756
# Iter 177: Loss=1.4287, Noise=0.9752
# Iter 178: Loss=1.4286, Noise=0.9751
# Iter 179: Loss=1.4287, Noise=0.9755
# Iter 180: Loss=1.4288, Noise=0.9757
# Iter 181: Loss=1.4288, Noise=0.9759
# Iter 182: Loss=1.4288, Noise=0.9764
# Iter 183: Loss=1.4286, Noise=0.9763
# Iter 184: Loss=1.4286, Noise=0.9760
# Iter 185: Loss=1.4288, Noise=0.9761
# Iter 186: Loss=1.4288, Noise=0.9767
# Iter 187: Loss=1.4289, Noise=0.9778
# Iter 188: Loss=1.4286, Noise=0.9783
# Iter 189: Loss=1.4285, Noise=0.9784
# Iter 190: Loss=1.4286, Noise=0.9787
# Iter 191: Loss=1.4286, Noise=0.9789
# Iter 192: Loss=1.4288, Noise=0.9798
# Iter 193: Loss=1.4286, Noise=0.9814
# Iter 194: Loss=1.4286, Noise=0.9822
# Iter 195: Loss=1.4287, Noise=0.9827
# Iter 196: Loss=1.4286, Noise=0.9834
# Iter 197: Loss=1.4286, Noise=0.9852
# Iter 198: Loss=1.4287, Noise=0.9869
# Iter 199: Loss=1.4287, Noise=0.9886
# Iter 200: Loss=1.4288, Noise=0.9899
# Iter 201: Loss=1.4287, Noise=0.9908
# Iter 202: Loss=1.4286, Noise=0.9906
# Iter 203: Loss=1.4286, Noise=0.9906
# Iter 204: Loss=1.4286, Noise=0.9895
# Iter 205: Loss=1.4289, Noise=0.9892
# Iter 206: Loss=1.4286, Noise=0.9891
# Iter 207: Loss=1.4288, Noise=0.9887
# Iter 208: Loss=1.4289, Noise=0.9880
# Iter 209: Loss=1.4286, Noise=0.9879
# Iter 210: Loss=1.4289, Noise=0.9877
# Iter 211: Loss=1.4286, Noise=0.9874
# Iter 212: Loss=1.4287, Noise=0.9874
# Iter 213: Loss=1.4287, Noise=0.9876
# Iter 214: Loss=1.4286, Noise=0.9873
# Iter 215: Loss=1.4287, Noise=0.9865
# Iter 216: Loss=1.4285, Noise=0.9855
# Iter 217: Loss=1.4288, Noise=0.9846
# Iter 218: Loss=1.4288, Noise=0.9837
# Iter 219: Loss=1.4285, Noise=0.9821
# Iter 220: Loss=1.4288, Noise=0.9826
# Iter 221: Loss=1.4284, Noise=0.9834
# Iter 222: Loss=1.4286, Noise=0.9837
# Iter 223: Loss=1.4288, Noise=0.9846
# Iter 224: Loss=1.4289, Noise=0.9853
# Iter 225: Loss=1.4287, Noise=0.9855
# Iter 226: Loss=1.4287, Noise=0.9852
# Iter 227: Loss=1.4288, Noise=0.9838
# Iter 228: Loss=1.4286, Noise=0.9824
# Iter 229: Loss=1.4285, Noise=0.9809
# Iter 230: Loss=1.4288, Noise=0.9796
# Iter 231: Loss=1.4289, Noise=0.9791
# Iter 232: Loss=1.4285, Noise=0.9789
# Iter 233: Loss=1.4289, Noise=0.9787
# Iter 234: Loss=1.4288, Noise=0.9787
# Iter 235: Loss=1.4288, Noise=0.9788
# Iter 236: Loss=1.4287, Noise=0.9798
# Iter 237: Loss=1.4287, Noise=0.9811
# Iter 238: Loss=1.4286, Noise=0.9822
# Iter 239: Loss=1.4288, Noise=0.9821
# Iter 240: Loss=1.4287, Noise=0.9817
# Iter 241: Loss=1.4288, Noise=0.9812
# Iter 242: Loss=1.4288, Noise=0.9818
# Iter 243: Loss=1.4286, Noise=0.9835
# Iter 244: Loss=1.4288, Noise=0.9853
# Iter 245: Loss=1.4287, Noise=0.9864
# Iter 246: Loss=1.4287, Noise=0.9877
# Iter 247: Loss=1.4287, Noise=0.9890
# Iter 248: Loss=1.4287, Noise=0.9896
# Iter 249: Loss=1.4289, Noise=0.9901
# Iter 250: Loss=1.4290, Noise=0.9903
# Iter 251: Loss=1.4288, Noise=0.9900
# Iter 252: Loss=1.4287, Noise=0.9896
# Iter 253: Loss=1.4288, Noise=0.9897
# Iter 254: Loss=1.4288, Noise=0.9896
# Iter 255: Loss=1.4285, Noise=0.9894
# Iter 256: Loss=1.4287, Noise=0.9896
# Iter 257: Loss=1.4288, Noise=0.9899
# Iter 258: Loss=1.4287, Noise=0.9902
# Iter 259: Loss=1.4287, Noise=0.9897
# Iter 260: Loss=1.4287, Noise=0.9885
# Iter 261: Loss=1.4287, Noise=0.9865
# Iter 262: Loss=1.4286, Noise=0.9853
# Iter 263: Loss=1.4287, Noise=0.9848
# Iter 264: Loss=1.4287, Noise=0.9837
# Iter 265: Loss=1.4286, Noise=0.9822
# Iter 266: Loss=1.4287, Noise=0.9819
# Iter 267: Loss=1.4288, Noise=0.9807
# Iter 268: Loss=1.4287, Noise=0.9802
# Iter 269: Loss=1.4285, Noise=0.9804
# Iter 270: Loss=1.4288, Noise=0.9813
# Iter 271: Loss=1.4289, Noise=0.9815
# Iter 272: Loss=1.4287, Noise=0.9811
# Iter 273: Loss=1.4287, Noise=0.9817
# Iter 274: Loss=1.4286, Noise=0.9828
# Iter 275: Loss=1.4286, Noise=0.9846
# Iter 276: Loss=1.4288, Noise=0.9859
# Iter 277: Loss=1.4287, Noise=0.9875
# Iter 278: Loss=1.4287, Noise=0.9880
# Iter 279: Loss=1.4286, Noise=0.9891
# Iter 280: Loss=1.4286, Noise=0.9909
# Iter 281: Loss=1.4286, Noise=0.9926
# Iter 282: Loss=1.4286, Noise=0.9931
# Iter 283: Loss=1.4288, Noise=0.9923
# Iter 284: Loss=1.4287, Noise=0.9911
# Iter 285: Loss=1.4286, Noise=0.9900
# Iter 286: Loss=1.4287, Noise=0.9882
# Iter 287: Loss=1.4287, Noise=0.9869
# Iter 288: Loss=1.4285, Noise=0.9857
# Iter 289: Loss=1.4288, Noise=0.9839
# Iter 290: Loss=1.4287, Noise=0.9814
# Iter 291: Loss=1.4287, Noise=0.9783
# Iter 292: Loss=1.4286, Noise=0.9766
# Iter 293: Loss=1.4286, Noise=0.9754
# Iter 294: Loss=1.4285, Noise=0.9738
# Iter 295: Loss=1.4287, Noise=0.9741
# Iter 296: Loss=1.4289, Noise=0.9743
# Iter 297: Loss=1.4287, Noise=0.9739
# Iter 298: Loss=1.4288, Noise=0.9733
# Iter 299: Loss=1.4287, Noise=0.9739
# Iter 300: Loss=1.4288, Noise=0.9753
# Iter 301: Loss=1.4288, Noise=0.9768
# Iter 302: Loss=1.4286, Noise=0.9784
# Iter 303: Loss=1.4286, Noise=0.9792
# Iter 304: Loss=1.4287, Noise=0.9806
# Iter 305: Loss=1.4286, Noise=0.9815
# Iter 306: Loss=1.4288, Noise=0.9838
# Iter 307: Loss=1.4285, Noise=0.9859
# Iter 308: Loss=1.4287, Noise=0.9872
# Iter 309: Loss=1.4289, Noise=0.9896
# Iter 310: Loss=1.4286, Noise=0.9910
# Iter 311: Loss=1.4286, Noise=0.9923
# Iter 312: Loss=1.4287, Noise=0.9924
# Iter 313: Loss=1.4288, Noise=0.9930
# Iter 314: Loss=1.4287, Noise=0.9925
# Iter 315: Loss=1.4288, Noise=0.9919
# Iter 316: Loss=1.4286, Noise=0.9914
# Iter 317: Loss=1.4287, Noise=0.9915
# Iter 318: Loss=1.4288, Noise=0.9916
# Iter 319: Loss=1.4288, Noise=0.9909
# Iter 320: Loss=1.4287, Noise=0.9905
# Iter 321: Loss=1.4288, Noise=0.9903
# Iter 322: Loss=1.4288, Noise=0.9901
# Iter 323: Loss=1.4288, Noise=0.9894
# Iter 324: Loss=1.4287, Noise=0.9894
# Iter 325: Loss=1.4288, Noise=0.9893
# Iter 326: Loss=1.4286, Noise=0.9896
# Iter 327: Loss=1.4287, Noise=0.9898
# Iter 328: Loss=1.4287, Noise=0.9896
# Iter 329: Loss=1.4286, Noise=0.9889
# Iter 330: Loss=1.4285, Noise=0.9883
# Iter 331: Loss=1.4287, Noise=0.9879
# Iter 332: Loss=1.4287, Noise=0.9868
# Iter 333: Loss=1.4288, Noise=0.9849
# Iter 334: Loss=1.4288, Noise=0.9821
# Iter 335: Loss=1.4285, Noise=0.9790
# Iter 336: Loss=1.4286, Noise=0.9758
# Iter 337: Loss=1.4287, Noise=0.9736
# Iter 338: Loss=1.4287, Noise=0.9722
# Iter 339: Loss=1.4288, Noise=0.9718
# Iter 340: Loss=1.4288, Noise=0.9712
# Iter 341: Loss=1.4289, Noise=0.9704
# Iter 342: Loss=1.4289, Noise=0.9695
# Iter 343: Loss=1.4288, Noise=0.9693
# Iter 344: Loss=1.4288, Noise=0.9699
# Iter 345: Loss=1.4288, Noise=0.9713
# Iter 346: Loss=1.4287, Noise=0.9722
# Iter 347: Loss=1.4286, Noise=0.9739
# Iter 348: Loss=1.4287, Noise=0.9753
# Iter 349: Loss=1.4287, Noise=0.9768
# Iter 350: Loss=1.4288, Noise=0.9789
# Iter 351: Loss=1.4287, Noise=0.9810
# Iter 352: Loss=1.4287, Noise=0.9834
# Iter 353: Loss=1.4289, Noise=0.9861
# Iter 354: Loss=1.4285, Noise=0.9880
# Iter 355: Loss=1.4288, Noise=0.9890
# Iter 356: Loss=1.4286, Noise=0.9887
# Iter 357: Loss=1.4287, Noise=0.9885
# Iter 358: Loss=1.4288, Noise=0.9885
# Iter 359: Loss=1.4288, Noise=0.9894
# Iter 360: Loss=1.4287, Noise=0.9909
# Iter 361: Loss=1.4287, Noise=0.9909
# Iter 362: Loss=1.4287, Noise=0.9904
# Iter 363: Loss=1.4286, Noise=0.9905
# Iter 364: Loss=1.4285, Noise=0.9902
# Iter 365: Loss=1.4287, Noise=0.9895
# Iter 366: Loss=1.4288, Noise=0.9894
# Iter 367: Loss=1.4288, Noise=0.9887
# Iter 368: Loss=1.4289, Noise=0.9881
# Iter 369: Loss=1.4288, Noise=0.9873
# Iter 370: Loss=1.4287, Noise=0.9865
# Iter 371: Loss=1.4287, Noise=0.9856
# Iter 372: Loss=1.4289, Noise=0.9843
# Iter 373: Loss=1.4286, Noise=0.9839
# Iter 374: Loss=1.4287, Noise=0.9834
# Iter 375: Loss=1.4287, Noise=0.9822
# Iter 376: Loss=1.4285, Noise=0.9811
# Iter 377: Loss=1.4288, Noise=0.9813
# Iter 378: Loss=1.4285, Noise=0.9811
# Iter 379: Loss=1.4287, Noise=0.9818
# Iter 380: Loss=1.4287, Noise=0.9828
# Iter 381: Loss=1.4288, Noise=0.9850
# Iter 382: Loss=1.4285, Noise=0.9865
# Iter 383: Loss=1.4287, Noise=0.9882
# Iter 384: Loss=1.4285, Noise=0.9900
# Iter 385: Loss=1.4287, Noise=0.9918
# Iter 386: Loss=1.4288, Noise=0.9932
# Iter 387: Loss=1.4283, Noise=0.9948
# Iter 388: Loss=1.4285, Noise=0.9955
# Iter 389: Loss=1.4288, Noise=0.9952
# Iter 390: Loss=1.4286, Noise=0.9950
# Iter 391: Loss=1.4287, Noise=0.9956
# Iter 392: Loss=1.4287, Noise=0.9956
# Iter 393: Loss=1.4287, Noise=0.9962
# Iter 394: Loss=1.4287, Noise=0.9984
# Iter 395: Loss=1.4287, Noise=1.0001
# Iter 396: Loss=1.4288, Noise=1.0013
# Iter 397: Loss=1.4286, Noise=1.0017
# Iter 398: Loss=1.4287, Noise=1.0013
# Iter 399: Loss=1.4287, Noise=1.0005
# Iter 400: Loss=1.4288, Noise=0.9988
# Iter 401: Loss=1.4286, Noise=0.9964
# Iter 402: Loss=1.4287, Noise=0.9927
# Iter 403: Loss=1.4286, Noise=0.9892
# Iter 404: Loss=1.4287, Noise=0.9860
# Iter 405: Loss=1.4286, Noise=0.9828
# Iter 406: Loss=1.4287, Noise=0.9801
# Iter 407: Loss=1.4285, Noise=0.9774
# Iter 408: Loss=1.4287, Noise=0.9747
# Iter 409: Loss=1.4288, Noise=0.9726
# Iter 410: Loss=1.4287, Noise=0.9718
# Iter 411: Loss=1.4287, Noise=0.9713
# Iter 412: Loss=1.4289, Noise=0.9715
# Iter 413: Loss=1.4290, Noise=0.9724
# Iter 414: Loss=1.4287, Noise=0.9737
# Iter 415: Loss=1.4288, Noise=0.9755
# Iter 416: Loss=1.4289, Noise=0.9772
# Iter 417: Loss=1.4288, Noise=0.9797
# Iter 418: Loss=1.4287, Noise=0.9819
# Iter 419: Loss=1.4287, Noise=0.9847
# Iter 420: Loss=1.4288, Noise=0.9867
# Iter 421: Loss=1.4287, Noise=0.9886
# Iter 422: Loss=1.4289, Noise=0.9904
# Iter 423: Loss=1.4286, Noise=0.9921
# Iter 424: Loss=1.4286, Noise=0.9938
# Iter 425: Loss=1.4287, Noise=0.9938
# Iter 426: Loss=1.4285, Noise=0.9924
# Iter 427: Loss=1.4288, Noise=0.9899
# Iter 428: Loss=1.4288, Noise=0.9875
# Iter 429: Loss=1.4287, Noise=0.9857
# Iter 430: Loss=1.4289, Noise=0.9835
# Iter 431: Loss=1.4287, Noise=0.9816
# Iter 432: Loss=1.4288, Noise=0.9794
# Iter 433: Loss=1.4285, Noise=0.9770
# Iter 434: Loss=1.4288, Noise=0.9736
# Iter 435: Loss=1.4288, Noise=0.9709
# Iter 436: Loss=1.4287, Noise=0.9691
# Iter 437: Loss=1.4287, Noise=0.9679
# Iter 438: Loss=1.4289, Noise=0.9669
# Iter 439: Loss=1.4288, Noise=0.9672
# Iter 440: Loss=1.4288, Noise=0.9676
# Iter 441: Loss=1.4288, Noise=0.9678
# Iter 442: Loss=1.4288, Noise=0.9692
# Iter 443: Loss=1.4289, Noise=0.9705
# Iter 444: Loss=1.4287, Noise=0.9711
# Iter 445: Loss=1.4287, Noise=0.9712
# Iter 446: Loss=1.4287, Noise=0.9726
# Iter 447: Loss=1.4288, Noise=0.9748
# Iter 448: Loss=1.4289, Noise=0.9775
# Iter 449: Loss=1.4287, Noise=0.9800
# Iter 450: Loss=1.4287, Noise=0.9823
# Iter 451: Loss=1.4285, Noise=0.9851
# Iter 452: Loss=1.4287, Noise=0.9875
# Iter 453: Loss=1.4286, Noise=0.9912
# Iter 454: Loss=1.4286, Noise=0.9955
# Iter 455: Loss=1.4288, Noise=0.9988
# Iter 456: Loss=1.4286, Noise=1.0016
# Iter 457: Loss=1.4288, Noise=1.0036
# Iter 458: Loss=1.4288, Noise=1.0043
# Iter 459: Loss=1.4289, Noise=1.0049
# Iter 460: Loss=1.4287, Noise=1.0049
# Iter 461: Loss=1.4289, Noise=1.0047
# Iter 462: Loss=1.4287, Noise=1.0046
# Iter 463: Loss=1.4288, Noise=1.0050
# Iter 464: Loss=1.4286, Noise=1.0056
# Iter 465: Loss=1.4288, Noise=1.0059
# Iter 466: Loss=1.4287, Noise=1.0063
# Iter 467: Loss=1.4289, Noise=1.0067
# Iter 468: Loss=1.4289, Noise=1.0072
# Iter 469: Loss=1.4288, Noise=1.0068
# Iter 470: Loss=1.4287, Noise=1.0054
# Iter 471: Loss=1.4289, Noise=1.0046
# Iter 472: Loss=1.4288, Noise=1.0035
# Iter 473: Loss=1.4287, Noise=1.0016
# Iter 474: Loss=1.4288, Noise=1.0000
# Iter 475: Loss=1.4288, Noise=0.9980
# Iter 476: Loss=1.4288, Noise=0.9955
# Iter 477: Loss=1.4286, Noise=0.9938
# Iter 478: Loss=1.4287, Noise=0.9927
# Iter 479: Loss=1.4288, Noise=0.9908
# Iter 480: Loss=1.4287, Noise=0.9893
# Iter 481: Loss=1.4286, Noise=0.9878
# Iter 482: Loss=1.4288, Noise=0.9873
# Iter 483: Loss=1.4286, Noise=0.9875
# Iter 484: Loss=1.4286, Noise=0.9876
# Iter 485: Loss=1.4287, Noise=0.9887
# Iter 486: Loss=1.4287, Noise=0.9895
# Iter 487: Loss=1.4285, Noise=0.9898
# Iter 488: Loss=1.4288, Noise=0.9897
# Iter 489: Loss=1.4288, Noise=0.9909
# Iter 490: Loss=1.4288, Noise=0.9924
# Iter 491: Loss=1.4287, Noise=0.9928
# Iter 492: Loss=1.4287, Noise=0.9923
# Iter 493: Loss=1.4285, Noise=0.9907
# Iter 494: Loss=1.4286, Noise=0.9876
# Iter 495: Loss=1.4286, Noise=0.9845
# Iter 496: Loss=1.4288, Noise=0.9820
# Iter 497: Loss=1.4286, Noise=0.9796
# Iter 498: Loss=1.4287, Noise=0.9780
# Iter 499: Loss=1.4289, Noise=0.9775
# Iter 500: Loss=1.4289, Noise=0.9775
# Iter 501: Loss=1.4285, Noise=0.9780
# Iter 502: Loss=1.4286, Noise=0.9784
# Iter 503: Loss=1.4288, Noise=0.9797
# Iter 504: Loss=1.4287, Noise=0.9797
# Iter 505: Loss=1.4287, Noise=0.9803
# Iter 506: Loss=1.4286, Noise=0.9802
# Iter 507: Loss=1.4287, Noise=0.9798
# Iter 508: Loss=1.4287, Noise=0.9802
# Iter 509: Loss=1.4288, Noise=0.9801
# Iter 510: Loss=1.4287, Noise=0.9809
# Iter 511: Loss=1.4286, Noise=0.9808
# Iter 512: Loss=1.4288, Noise=0.9801
# Iter 513: Loss=1.4286, Noise=0.9786
# Iter 514: Loss=1.4288, Noise=0.9776
# Iter 515: Loss=1.4286, Noise=0.9769
# Iter 516: Loss=1.4287, Noise=0.9758
# Iter 517: Loss=1.4287, Noise=0.9749
# Iter 518: Loss=1.4288, Noise=0.9738
# Iter 519: Loss=1.4288, Noise=0.9725
# Iter 520: Loss=1.4286, Noise=0.9711
# Iter 521: Loss=1.4288, Noise=0.9707
# Iter 522: Loss=1.4287, Noise=0.9706
# Iter 523: Loss=1.4288, Noise=0.9709
# Iter 524: Loss=1.4288, Noise=0.9703
# Iter 525: Loss=1.4289, Noise=0.9702
# Iter 526: Loss=1.4288, Noise=0.9702
# Iter 527: Loss=1.4288, Noise=0.9711
# Iter 528: Loss=1.4289, Noise=0.9727
# Iter 529: Loss=1.4287, Noise=0.9746
# Iter 530: Loss=1.4287, Noise=0.9765
# Iter 531: Loss=1.4286, Noise=0.9793
# Iter 532: Loss=1.4287, Noise=0.9815
# Iter 533: Loss=1.4287, Noise=0.9841
# Iter 534: Loss=1.4288, Noise=0.9863
# Iter 535: Loss=1.4285, Noise=0.9878
# Iter 536: Loss=1.4288, Noise=0.9894
# Iter 537: Loss=1.4286, Noise=0.9910
# Iter 538: Loss=1.4287, Noise=0.9916
# Iter 539: Loss=1.4287, Noise=0.9925
# Iter 540: Loss=1.4287, Noise=0.9938
# Iter 541: Loss=1.4288, Noise=0.9938
# Iter 542: Loss=1.4287, Noise=0.9935
# Iter 543: Loss=1.4289, Noise=0.9931
# Iter 544: Loss=1.4288, Noise=0.9926
# Iter 545: Loss=1.4288, Noise=0.9925
# Iter 546: Loss=1.4287, Noise=0.9921
# Iter 547: Loss=1.4287, Noise=0.9917
# Iter 548: Loss=1.4287, Noise=0.9917
# Iter 549: Loss=1.4288, Noise=0.9917
# Iter 550: Loss=1.4288, Noise=0.9923
# Iter 551: Loss=1.4288, Noise=0.9930
# Iter 552: Loss=1.4287, Noise=0.9924
# Iter 553: Loss=1.4288, Noise=0.9921
# Iter 554: Loss=1.4288, Noise=0.9917
# Iter 555: Loss=1.4287, Noise=0.9909
# Iter 556: Loss=1.4287, Noise=0.9901
# Iter 557: Loss=1.4287, Noise=0.9890
# Iter 558: Loss=1.4287, Noise=0.9867
# Iter 559: Loss=1.4286, Noise=0.9848
# Iter 560: Loss=1.4285, Noise=0.9831
# Iter 561: Loss=1.4286, Noise=0.9803
# Iter 562: Loss=1.4286, Noise=0.9778
# Iter 563: Loss=1.4287, Noise=0.9764
# Iter 564: Loss=1.4286, Noise=0.9739
# Iter 565: Loss=1.4286, Noise=0.9713
# Iter 566: Loss=1.4288, Noise=0.9698
# Iter 567: Loss=1.4287, Noise=0.9693
# Iter 568: Loss=1.4289, Noise=0.9701
# Iter 569: Loss=1.4287, Noise=0.9710
# Iter 570: Loss=1.4288, Noise=0.9715
# Iter 571: Loss=1.4287, Noise=0.9737
# Iter 572: Loss=1.4286, Noise=0.9756
# Iter 573: Loss=1.4287, Noise=0.9771
# Iter 574: Loss=1.4286, Noise=0.9787
# Iter 575: Loss=1.4286, Noise=0.9796
# Iter 576: Loss=1.4285, Noise=0.9809
# Iter 577: Loss=1.4288, Noise=0.9827
# Iter 578: Loss=1.4289, Noise=0.9845
# Iter 579: Loss=1.4285, Noise=0.9864
# Iter 580: Loss=1.4287, Noise=0.9887
# Iter 581: Loss=1.4287, Noise=0.9907
# Iter 582: Loss=1.4287, Noise=0.9936
# Iter 583: Loss=1.4285, Noise=0.9963
# Iter 584: Loss=1.4288, Noise=0.9987
# Iter 585: Loss=1.4286, Noise=1.0013
# Iter 586: Loss=1.4287, Noise=1.0032
# Iter 587: Loss=1.4288, Noise=1.0055
# Iter 588: Loss=1.4289, Noise=1.0070
# Iter 589: Loss=1.4288, Noise=1.0077
# Iter 590: Loss=1.4288, Noise=1.0077
# Iter 591: Loss=1.4287, Noise=1.0072
# Iter 592: Loss=1.4286, Noise=1.0057
# Iter 593: Loss=1.4289, Noise=1.0046
# Iter 594: Loss=1.4288, Noise=1.0029
# Iter 595: Loss=1.4289, Noise=1.0006
# Iter 596: Loss=1.4288, Noise=0.9986
# Iter 597: Loss=1.4286, Noise=0.9976
# Iter 598: Loss=1.4287, Noise=0.9958
# Iter 599: Loss=1.4286, Noise=0.9936
# Iter 600: Loss=1.4288, Noise=0.9921
# Iter 601: Loss=1.4285, Noise=0.9908
# Iter 602: Loss=1.4287, Noise=0.9891
# Iter 603: Loss=1.4286, Noise=0.9865
# Iter 604: Loss=1.4289, Noise=0.9839
# Iter 605: Loss=1.4287, Noise=0.9807
# Iter 606: Loss=1.4287, Noise=0.9777
# Iter 607: Loss=1.4286, Noise=0.9764
# Iter 608: Loss=1.4287, Noise=0.9753
# Iter 609: Loss=1.4288, Noise=0.9750
# Iter 610: Loss=1.4288, Noise=0.9751
# Iter 611: Loss=1.4290, Noise=0.9751
# Iter 612: Loss=1.4287, Noise=0.9748
# Iter 613: Loss=1.4288, Noise=0.9740
# Iter 614: Loss=1.4287, Noise=0.9729
# Iter 615: Loss=1.4289, Noise=0.9715
# Iter 616: Loss=1.4286, Noise=0.9701
# Iter 617: Loss=1.4288, Noise=0.9693
# Iter 618: Loss=1.4288, Noise=0.9693
# Iter 619: Loss=1.4287, Noise=0.9701
# Iter 620: Loss=1.4287, Noise=0.9708
# Iter 621: Loss=1.4286, Noise=0.9718
# Iter 622: Loss=1.4287, Noise=0.9736
# Iter 623: Loss=1.4286, Noise=0.9760
# Iter 624: Loss=1.4287, Noise=0.9770
# Iter 625: Loss=1.4289, Noise=0.9785
# Iter 626: Loss=1.4289, Noise=0.9802
# Iter 627: Loss=1.4288, Noise=0.9828
# Iter 628: Loss=1.4287, Noise=0.9858
# Iter 629: Loss=1.4289, Noise=0.9882
# Iter 630: Loss=1.4288, Noise=0.9901
# Iter 631: Loss=1.4288, Noise=0.9915
# Iter 632: Loss=1.4287, Noise=0.9920
# Iter 633: Loss=1.4287, Noise=0.9909
# Iter 634: Loss=1.4287, Noise=0.9901
# Iter 635: Loss=1.4287, Noise=0.9898
# Iter 636: Loss=1.4287, Noise=0.9899
# Iter 637: Loss=1.4287, Noise=0.9902
# Iter 638: Loss=1.4288, Noise=0.9907
# Iter 639: Loss=1.4287, Noise=0.9915
# Iter 640: Loss=1.4287, Noise=0.9919
# Iter 641: Loss=1.4288, Noise=0.9910
# Iter 642: Loss=1.4287, Noise=0.9897
# Iter 643: Loss=1.4288, Noise=0.9897
# Iter 644: Loss=1.4288, Noise=0.9884
# Iter 645: Loss=1.4288, Noise=0.9867
# Iter 646: Loss=1.4287, Noise=0.9848
# Iter 647: Loss=1.4287, Noise=0.9837
# Iter 648: Loss=1.4287, Noise=0.9825
# Iter 649: Loss=1.4288, Noise=0.9806
# Iter 650: Loss=1.4288, Noise=0.9788
# Iter 651: Loss=1.4287, Noise=0.9781
# Iter 652: Loss=1.4286, Noise=0.9780
# Iter 653: Loss=1.4289, Noise=0.9780
# Iter 654: Loss=1.4287, Noise=0.9789
# Iter 655: Loss=1.4287, Noise=0.9805
# Iter 656: Loss=1.4287, Noise=0.9825
# Iter 657: Loss=1.4287, Noise=0.9854
# Iter 658: Loss=1.4288, Noise=0.9886
# Iter 659: Loss=1.4288, Noise=0.9912
# Iter 660: Loss=1.4286, Noise=0.9941
# Iter 661: Loss=1.4289, Noise=0.9964
# Iter 662: Loss=1.4288, Noise=0.9976
# Iter 663: Loss=1.4287, Noise=0.9982
# Iter 664: Loss=1.4289, Noise=0.9981
# Iter 665: Loss=1.4287, Noise=0.9990
# Iter 666: Loss=1.4286, Noise=0.9994
# Iter 667: Loss=1.4287, Noise=0.9989
# Iter 668: Loss=1.4286, Noise=0.9982
# Iter 669: Loss=1.4287, Noise=0.9976
# Iter 670: Loss=1.4289, Noise=0.9962
# Iter 671: Loss=1.4286, Noise=0.9945
# Iter 672: Loss=1.4288, Noise=0.9933
# Iter 673: Loss=1.4288, Noise=0.9909
# Iter 674: Loss=1.4289, Noise=0.9886
# Iter 675: Loss=1.4286, Noise=0.9863
# Iter 676: Loss=1.4286, Noise=0.9847
# Iter 677: Loss=1.4287, Noise=0.9822
# Iter 678: Loss=1.4288, Noise=0.9802
# Iter 679: Loss=1.4286, Noise=0.9780
# Iter 680: Loss=1.4287, Noise=0.9767
# Iter 681: Loss=1.4289, Noise=0.9753
# Iter 682: Loss=1.4288, Noise=0.9758
# Iter 683: Loss=1.4289, Noise=0.9759
# Iter 684: Loss=1.4286, Noise=0.9759
# Iter 685: Loss=1.4287, Noise=0.9765
# Iter 686: Loss=1.4286, Noise=0.9773
# Iter 687: Loss=1.4288, Noise=0.9783
# Iter 688: Loss=1.4287, Noise=0.9788
# Iter 689: Loss=1.4287, Noise=0.9799
# Iter 690: Loss=1.4288, Noise=0.9810
# Iter 691: Loss=1.4288, Noise=0.9831
# Iter 692: Loss=1.4287, Noise=0.9856
# Iter 693: Loss=1.4287, Noise=0.9883
# Iter 694: Loss=1.4287, Noise=0.9905
# Iter 695: Loss=1.4285, Noise=0.9929
# Iter 696: Loss=1.4287, Noise=0.9936
# Iter 697: Loss=1.4288, Noise=0.9943
# Iter 698: Loss=1.4286, Noise=0.9951
# Iter 699: Loss=1.4288, Noise=0.9952
# Iter 700: Loss=1.4286, Noise=0.9949
# Iter 701: Loss=1.4288, Noise=0.9937
# Iter 702: Loss=1.4287, Noise=0.9920
# Iter 703: Loss=1.4287, Noise=0.9896
# Iter 704: Loss=1.4287, Noise=0.9865
# Iter 705: Loss=1.4286, Noise=0.9834
# Iter 706: Loss=1.4287, Noise=0.9808
# Iter 707: Loss=1.4287, Noise=0.9783
# Iter 708: Loss=1.4287, Noise=0.9756
# Iter 709: Loss=1.4287, Noise=0.9734
# Iter 710: Loss=1.4286, Noise=0.9726
# Iter 711: Loss=1.4287, Noise=0.9724
# Iter 712: Loss=1.4287, Noise=0.9721
# Iter 713: Loss=1.4286, Noise=0.9723
# Iter 714: Loss=1.4285, Noise=0.9733
# Iter 715: Loss=1.4287, Noise=0.9748
# Iter 716: Loss=1.4285, Noise=0.9770
# Iter 717: Loss=1.4287, Noise=0.9789
# Iter 718: Loss=1.4287, Noise=0.9816
# Iter 719: Loss=1.4288, Noise=0.9841
# Iter 720: Loss=1.4289, Noise=0.9862
# Iter 721: Loss=1.4288, Noise=0.9886
# Iter 722: Loss=1.4286, Noise=0.9902
# Iter 723: Loss=1.4289, Noise=0.9914
# Iter 724: Loss=1.4287, Noise=0.9926
# Iter 725: Loss=1.4286, Noise=0.9925
# Iter 726: Loss=1.4288, Noise=0.9928
# Iter 727: Loss=1.4287, Noise=0.9925
# Iter 728: Loss=1.4287, Noise=0.9933
# Iter 729: Loss=1.4288, Noise=0.9943
# Iter 730: Loss=1.4287, Noise=0.9952
# Iter 731: Loss=1.4288, Noise=0.9966
# Iter 732: Loss=1.4290, Noise=0.9977
# Iter 733: Loss=1.4288, Noise=0.9985
# Iter 734: Loss=1.4288, Noise=0.9991
# Iter 735: Loss=1.4288, Noise=1.0002
# Iter 736: Loss=1.4286, Noise=1.0010
# Iter 737: Loss=1.4287, Noise=1.0015
# Iter 738: Loss=1.4288, Noise=1.0002
# Iter 739: Loss=1.4287, Noise=0.9989
# Iter 740: Loss=1.4287, Noise=0.9974
# Iter 741: Loss=1.4286, Noise=0.9954
# Iter 742: Loss=1.4288, Noise=0.9931
# Iter 743: Loss=1.4289, Noise=0.9902
# Iter 744: Loss=1.4288, Noise=0.9879
# Iter 745: Loss=1.4286, Noise=0.9848
# Iter 746: Loss=1.4286, Noise=0.9821
# Iter 747: Loss=1.4288, Noise=0.9798
# Iter 748: Loss=1.4286, Noise=0.9781
# Iter 749: Loss=1.4286, Noise=0.9771
# Iter 750: Loss=1.4286, Noise=0.9753
# Iter 751: Loss=1.4285, Noise=0.9736
# Iter 752: Loss=1.4288, Noise=0.9735
# Iter 753: Loss=1.4287, Noise=0.9736
# Iter 754: Loss=1.4288, Noise=0.9738
# Iter 755: Loss=1.4287, Noise=0.9737
# Iter 756: Loss=1.4286, Noise=0.9737
# Iter 757: Loss=1.4285, Noise=0.9735
# Iter 758: Loss=1.4285, Noise=0.9733
# Iter 759: Loss=1.4289, Noise=0.9736
# Iter 760: Loss=1.4287, Noise=0.9737
# Iter 761: Loss=1.4287, Noise=0.9734
# Iter 762: Loss=1.4288, Noise=0.9732
# Iter 763: Loss=1.4286, Noise=0.9721
# Iter 764: Loss=1.4288, Noise=0.9711
# Iter 765: Loss=1.4287, Noise=0.9701
# Iter 766: Loss=1.4287, Noise=0.9696
# Iter 767: Loss=1.4288, Noise=0.9695
# Iter 768: Loss=1.4287, Noise=0.9706
# Iter 769: Loss=1.4286, Noise=0.9727
# Iter 770: Loss=1.4287, Noise=0.9750
# Iter 771: Loss=1.4287, Noise=0.9781
# Iter 772: Loss=1.4286, Noise=0.9808
# Iter 773: Loss=1.4286, Noise=0.9831
# Iter 774: Loss=1.4290, Noise=0.9851
# Iter 775: Loss=1.4286, Noise=0.9866
# Iter 776: Loss=1.4289, Noise=0.9870
# Iter 777: Loss=1.4286, Noise=0.9888
# Iter 778: Loss=1.4288, Noise=0.9902
# Iter 779: Loss=1.4287, Noise=0.9927
# Iter 780: Loss=1.4287, Noise=0.9945
# Iter 781: Loss=1.4288, Noise=0.9966
# Iter 782: Loss=1.4288, Noise=0.9985
# Iter 783: Loss=1.4288, Noise=0.9990
# Iter 784: Loss=1.4287, Noise=0.9989
# Iter 785: Loss=1.4286, Noise=0.9990
# Iter 786: Loss=1.4286, Noise=0.9983
# Iter 787: Loss=1.4286, Noise=0.9974
# Iter 788: Loss=1.4287, Noise=0.9960
# Iter 789: Loss=1.4286, Noise=0.9951
# Iter 790: Loss=1.4287, Noise=0.9935
# Iter 791: Loss=1.4287, Noise=0.9919
# Iter 792: Loss=1.4286, Noise=0.9905
# Iter 793: Loss=1.4287, Noise=0.9882
# Iter 794: Loss=1.4287, Noise=0.9861
# Iter 795: Loss=1.4288, Noise=0.9846
# Iter 796: Loss=1.4287, Noise=0.9832
# Iter 797: Loss=1.4287, Noise=0.9826
# Iter 798: Loss=1.4287, Noise=0.9819
# Iter 799: Loss=1.4288, Noise=0.9800
# Iter 800: Loss=1.4288, Noise=0.9782
# Iter 801: Loss=1.4286, Noise=0.9774
# Iter 802: Loss=1.4289, Noise=0.9771
# Iter 803: Loss=1.4288, Noise=0.9768
# Iter 804: Loss=1.4288, Noise=0.9758
# Iter 805: Loss=1.4287, Noise=0.9734
# Iter 806: Loss=1.4289, Noise=0.9714
# Iter 807: Loss=1.4288, Noise=0.9702
# Iter 808: Loss=1.4288, Noise=0.9694
# Iter 809: Loss=1.4287, Noise=0.9691
# Iter 810: Loss=1.4286, Noise=0.9702
# Iter 811: Loss=1.4287, Noise=0.9707
# Iter 812: Loss=1.4289, Noise=0.9718
# Iter 813: Loss=1.4288, Noise=0.9743
# Iter 814: Loss=1.4287, Noise=0.9767
# Iter 815: Loss=1.4285, Noise=0.9794
# Iter 816: Loss=1.4287, Noise=0.9820
# Iter 817: Loss=1.4287, Noise=0.9838
# Iter 818: Loss=1.4285, Noise=0.9856
# Iter 819: Loss=1.4287, Noise=0.9875
# Iter 820: Loss=1.4287, Noise=0.9881
# Iter 821: Loss=1.4287, Noise=0.9888
# Iter 822: Loss=1.4287, Noise=0.9888
# Iter 823: Loss=1.4286, Noise=0.9893
# Iter 824: Loss=1.4286, Noise=0.9891
# Iter 825: Loss=1.4287, Noise=0.9883
# Iter 826: Loss=1.4287, Noise=0.9879
# Iter 827: Loss=1.4288, Noise=0.9871
# Iter 828: Loss=1.4288, Noise=0.9871
# Iter 829: Loss=1.4289, Noise=0.9872
# Iter 830: Loss=1.4288, Noise=0.9871
# Iter 831: Loss=1.4288, Noise=0.9873
# Iter 832: Loss=1.4287, Noise=0.9883
# Iter 833: Loss=1.4288, Noise=0.9895
# Iter 834: Loss=1.4288, Noise=0.9910
# Iter 835: Loss=1.4288, Noise=0.9922
# Iter 836: Loss=1.4288, Noise=0.9926
# Iter 837: Loss=1.4287, Noise=0.9930
# Iter 838: Loss=1.4289, Noise=0.9936
# Iter 839: Loss=1.4286, Noise=0.9943
# Iter 840: Loss=1.4288, Noise=0.9953
# Iter 841: Loss=1.4286, Noise=0.9963
# Iter 842: Loss=1.4288, Noise=0.9975
# Iter 843: Loss=1.4288, Noise=0.9973
# Iter 844: Loss=1.4287, Noise=0.9973
# Iter 845: Loss=1.4287, Noise=0.9967
# Iter 846: Loss=1.4287, Noise=0.9961
# Iter 847: Loss=1.4287, Noise=0.9954
# Iter 848: Loss=1.4287, Noise=0.9948
# Iter 849: Loss=1.4287, Noise=0.9936
# Iter 850: Loss=1.4288, Noise=0.9924
# Iter 851: Loss=1.4287, Noise=0.9913
# Iter 852: Loss=1.4289, Noise=0.9904
# Iter 853: Loss=1.4285, Noise=0.9889
# Iter 854: Loss=1.4287, Noise=0.9868
# Iter 855: Loss=1.4288, Noise=0.9855
# Iter 856: Loss=1.4285, Noise=0.9841
# Iter 857: Loss=1.4288, Noise=0.9834
# Iter 858: Loss=1.4286, Noise=0.9836
# Iter 859: Loss=1.4288, Noise=0.9843
# Iter 860: Loss=1.4288, Noise=0.9846
# Iter 861: Loss=1.4286, Noise=0.9849
# Iter 862: Loss=1.4288, Noise=0.9858
# Iter 863: Loss=1.4289, Noise=0.9873
# Iter 864: Loss=1.4286, Noise=0.9878
# Iter 865: Loss=1.4287, Noise=0.9883
# Iter 866: Loss=1.4287, Noise=0.9889
# Iter 867: Loss=1.4286, Noise=0.9904
# Iter 868: Loss=1.4286, Noise=0.9901
# Iter 869: Loss=1.4288, Noise=0.9897
# Iter 870: Loss=1.4288, Noise=0.9887
# Iter 871: Loss=1.4286, Noise=0.9885
# Iter 872: Loss=1.4287, Noise=0.9886
# Iter 873: Loss=1.4287, Noise=0.9891
# Iter 874: Loss=1.4289, Noise=0.9900
# Iter 875: Loss=1.4286, Noise=0.9907
# Iter 876: Loss=1.4287, Noise=0.9907
# Iter 877: Loss=1.4289, Noise=0.9903
# Iter 878: Loss=1.4289, Noise=0.9897
# Iter 879: Loss=1.4288, Noise=0.9889
# Iter 880: Loss=1.4285, Noise=0.9893
# Iter 881: Loss=1.4287, Noise=0.9887
# Iter 882: Loss=1.4288, Noise=0.9879
# Iter 883: Loss=1.4287, Noise=0.9858
# Iter 884: Loss=1.4288, Noise=0.9842
# Iter 885: Loss=1.4286, Noise=0.9832
# Iter 886: Loss=1.4286, Noise=0.9826
# Iter 887: Loss=1.4288, Noise=0.9830
# Iter 888: Loss=1.4288, Noise=0.9832
# Iter 889: Loss=1.4288, Noise=0.9832
# Iter 890: Loss=1.4287, Noise=0.9843
# Iter 891: Loss=1.4288, Noise=0.9860
# Iter 892: Loss=1.4287, Noise=0.9882
# Iter 893: Loss=1.4288, Noise=0.9897
# Iter 894: Loss=1.4287, Noise=0.9913
# Iter 895: Loss=1.4288, Noise=0.9928
# Iter 896: Loss=1.4288, Noise=0.9939
# Iter 897: Loss=1.4287, Noise=0.9942
# Iter 898: Loss=1.4286, Noise=0.9945
# Iter 899: Loss=1.4288, Noise=0.9945
# Iter 900: Loss=1.4287, Noise=0.9935
# Iter 901: Loss=1.4288, Noise=0.9924
# Iter 902: Loss=1.4286, Noise=0.9920
# Iter 903: Loss=1.4286, Noise=0.9913
# Iter 904: Loss=1.4286, Noise=0.9906
# Iter 905: Loss=1.4287, Noise=0.9901
# Iter 906: Loss=1.4286, Noise=0.9889
# Iter 907: Loss=1.4286, Noise=0.9871
# Iter 908: Loss=1.4286, Noise=0.9863
# Iter 909: Loss=1.4286, Noise=0.9861
# Iter 910: Loss=1.4288, Noise=0.9854
# Iter 911: Loss=1.4284, Noise=0.9849
# Iter 912: Loss=1.4286, Noise=0.9846
# Iter 913: Loss=1.4285, Noise=0.9839
# Iter 914: Loss=1.4288, Noise=0.9836
# Iter 915: Loss=1.4288, Noise=0.9838
# Iter 916: Loss=1.4288, Noise=0.9838
# Iter 917: Loss=1.4287, Noise=0.9841
# Iter 918: Loss=1.4288, Noise=0.9846
# Iter 919: Loss=1.4288, Noise=0.9849
# Iter 920: Loss=1.4287, Noise=0.9853
# Iter 921: Loss=1.4287, Noise=0.9867
# Iter 922: Loss=1.4287, Noise=0.9875
# Iter 923: Loss=1.4288, Noise=0.9884
# Iter 924: Loss=1.4287, Noise=0.9894
# Iter 925: Loss=1.4286, Noise=0.9902
# Iter 926: Loss=1.4289, Noise=0.9901
# Iter 927: Loss=1.4286, Noise=0.9907
# Iter 928: Loss=1.4287, Noise=0.9909
# Iter 929: Loss=1.4286, Noise=0.9902
# Iter 930: Loss=1.4286, Noise=0.9883
# Iter 931: Loss=1.4288, Noise=0.9868
# Iter 932: Loss=1.4287, Noise=0.9859
# Iter 933: Loss=1.4287, Noise=0.9859
# Iter 934: Loss=1.4289, Noise=0.9850
# Iter 935: Loss=1.4284, Noise=0.9838
# Iter 936: Loss=1.4287, Noise=0.9824
# Iter 937: Loss=1.4288, Noise=0.9815
# Iter 938: Loss=1.4288, Noise=0.9813
# Iter 939: Loss=1.4287, Noise=0.9824
# Iter 940: Loss=1.4287, Noise=0.9841
# Iter 941: Loss=1.4287, Noise=0.9874
# Iter 942: Loss=1.4288, Noise=0.9903
# Iter 943: Loss=1.4288, Noise=0.9935
# Iter 944: Loss=1.4287, Noise=0.9969
# Iter 945: Loss=1.4286, Noise=0.9990
# Iter 946: Loss=1.4289, Noise=1.0020
# Iter 947: Loss=1.4286, Noise=1.0041
# Iter 948: Loss=1.4287, Noise=1.0056
# Iter 949: Loss=1.4287, Noise=1.0060
# Iter 950: Loss=1.4289, Noise=1.0063
# Iter 951: Loss=1.4289, Noise=1.0067
# Iter 952: Loss=1.4288, Noise=1.0051
# Iter 953: Loss=1.4288, Noise=1.0027
# Iter 954: Loss=1.4287, Noise=1.0002
# Iter 955: Loss=1.4289, Noise=0.9975
# Iter 956: Loss=1.4286, Noise=0.9949
# Iter 957: Loss=1.4288, Noise=0.9921
# Iter 958: Loss=1.4286, Noise=0.9902
# Iter 959: Loss=1.4286, Noise=0.9878
# Iter 960: Loss=1.4286, Noise=0.9858
# Iter 961: Loss=1.4288, Noise=0.9837
# Iter 962: Loss=1.4289, Noise=0.9814
# Iter 963: Loss=1.4287, Noise=0.9784
# Iter 964: Loss=1.4287, Noise=0.9752
# Iter 965: Loss=1.4288, Noise=0.9715
# Iter 966: Loss=1.4289, Noise=0.9684
# Iter 967: Loss=1.4287, Noise=0.9656
# Iter 968: Loss=1.4288, Noise=0.9649
# Iter 969: Loss=1.4288, Noise=0.9644
# Iter 970: Loss=1.4288, Noise=0.9648
# Iter 971: Loss=1.4287, Noise=0.9663
# Iter 972: Loss=1.4289, Noise=0.9685
# Iter 973: Loss=1.4286, Noise=0.9713
# Iter 974: Loss=1.4288, Noise=0.9744
# Iter 975: Loss=1.4288, Noise=0.9779
# Iter 976: Loss=1.4287, Noise=0.9815
# Iter 977: Loss=1.4289, Noise=0.9840
# Iter 978: Loss=1.4286, Noise=0.9858
# Iter 979: Loss=1.4286, Noise=0.9869
# Iter 980: Loss=1.4287, Noise=0.9882
# Iter 981: Loss=1.4287, Noise=0.9896
# Iter 982: Loss=1.4287, Noise=0.9904
# Iter 983: Loss=1.4287, Noise=0.9902
# Iter 984: Loss=1.4287, Noise=0.9903
# Iter 985: Loss=1.4287, Noise=0.9899
# Iter 986: Loss=1.4288, Noise=0.9900
# Iter 987: Loss=1.4288, Noise=0.9902
# Iter 988: Loss=1.4288, Noise=0.9905
# Iter 989: Loss=1.4286, Noise=0.9904
# Iter 990: Loss=1.4288, Noise=0.9908
# Iter 991: Loss=1.4286, Noise=0.9908
# Iter 992: Loss=1.4288, Noise=0.9905
# Iter 993: Loss=1.4287, Noise=0.9894
# Iter 994: Loss=1.4287, Noise=0.9897
# Iter 995: Loss=1.4287, Noise=0.9899
# Iter 996: Loss=1.4286, Noise=0.9886
# Iter 997: Loss=1.4287, Noise=0.9876
# Iter 998: Loss=1.4286, Noise=0.9869
# Iter 999: Loss=1.4285, Noise=0.9877

# %%
# Test the model
model.eval()
output = model(test_x)
rmse = (test_y - output.mean).pow(2).mean().sqrt().item()
neg_log_lik = -mll(output, test_y).item()
print('RMSE={:2.4f}, Neg Log Likelihood={:2.4f}'.format(rmse, neg_log_lik))
# Out:
# RMSE=0.9146, Neg Log Likelihood=1.3390

# %% [markdown]
# ### Create an DPA-GP-ARD model

# %%
# Draw random projections, `diversify` and store in a linear module
# Here, we are drawing 20 Gaussian projections into 1 dimension.
projs = [rp.gen_rp(d, 1, dist='gaussian') for _ in range(num_projs)] # initial directions

newW, _ = rp.space_equally(torch.cat(projs,dim=1).t(), lr=0.1, niter=5000) # Try to diversify
newW.requires_grad = False # Make sure they aren't trainable
projs = [newW[i:i+1, :].t() for i in range(0, num_projs, 1)]  # Reshape like initial directions

proj_module = torch.nn.Linear(d, num_projs, bias=False)
proj_module.weight.data = torch.cat(projs, dim=1).t()

# Create the additive model that operates over these projections
# Fixing the outputscale and lengthscale of the base kernels.
base_kernel = RBFKernel()
base_kernel.initialize(lengthscale=torch.tensor([1.]))
base_kernel = ScaleKernel(base_kernel)
base_kernel.initialize(outputscale=torch.tensor([1/num_projs]))

# Combine into a single module.
# Using prescale=True applies lengthscales to original input space, i.e. scaling pre-projection.
kernel = ScaledProjectionKernel(proj_module, base_kernel, 
                                prescale=True,  
                                ard_num_dims=d,
                                learn_proj=False)
# Or, just call the method from training_routines that wraps this initialization
# from training_routines import create_additive_rp_kernel
# create_additive_rp_kernel(d, num_projs, learn_proj=False, kernel_type='RBF', 
#                           space_proj=True, prescale=True, ard=True, k=1, 
#                           proj_dist='gaussian')

kernel = ScaleKernel(kernel) # Optionally wrap with an additional ScaleKernel 

# Create an ExactGP model with this kernel
likelihood = GaussianLikelihood()
likelihood.noise = 1.
model = ExactGPModel(train_x, train_y, GaussianLikelihood(), kernel)

# %% [markdown]
# ### Train the model

# %%
# Train the model
mll = ExactMarginalLogLikelihood(model.likelihood, model)
model.train()
model.likelihood.train()
optimizer = Adam(mll.parameters(), lr=0.01)
for iteration in range(1000):
    optimizer.zero_grad()
    output = model(train_x)
    loss = -mll(output, train_y)
    loss.backward()
    optimizer.step()
    msg = "Iter {}: Loss={:2.4f}, Noise={:2.4f}".format(iteration, loss.item(), model.likelihood.noise.item())
    print(msg)
# Out:
# Iter 0: Loss=1.4611, Noise=0.6983
# Iter 1: Loss=1.4591, Noise=0.7033
# Iter 2: Loss=1.4581, Noise=0.7084
# Iter 3: Loss=1.4563, Noise=0.7134
# Iter 4: Loss=1.4553, Noise=0.7185
# Iter 5: Loss=1.4539, Noise=0.7236
# Iter 6: Loss=1.4528, Noise=0.7287
# Iter 7: Loss=1.4515, Noise=0.7337
# Iter 8: Loss=1.4502, Noise=0.7387
# Iter 9: Loss=1.4492, Noise=0.7437
# Iter 10: Loss=1.4483, Noise=0.7486
# Iter 11: Loss=1.4474, Noise=0.7535
# Iter 12: Loss=1.4466, Noise=0.7584
# Iter 13: Loss=1.4452, Noise=0.7633
# Iter 14: Loss=1.4446, Noise=0.7682
# Iter 15: Loss=1.4438, Noise=0.7731
# Iter 16: Loss=1.4430, Noise=0.7779
# Iter 17: Loss=1.4421, Noise=0.7827
# Iter 18: Loss=1.4414, Noise=0.7875
# Iter 19: Loss=1.4406, Noise=0.7921
# Iter 20: Loss=1.4395, Noise=0.7969
# Iter 21: Loss=1.4391, Noise=0.8015
# Iter 22: Loss=1.4388, Noise=0.8062
# Iter 23: Loss=1.4380, Noise=0.8109
# Iter 24: Loss=1.4374, Noise=0.8155
# Iter 25: Loss=1.4368, Noise=0.8201
# Iter 26: Loss=1.4362, Noise=0.8247
# Iter 27: Loss=1.4358, Noise=0.8292
# Iter 28: Loss=1.4351, Noise=0.8336
# Iter 29: Loss=1.4350, Noise=0.8379
# Iter 30: Loss=1.4344, Noise=0.8421
# Iter 31: Loss=1.4343, Noise=0.8462
# Iter 32: Loss=1.4334, Noise=0.8503
# Iter 33: Loss=1.4334, Noise=0.8543
# Iter 34: Loss=1.4331, Noise=0.8583
# Iter 35: Loss=1.4327, Noise=0.8621
# Iter 36: Loss=1.4324, Noise=0.8658
# Iter 37: Loss=1.4322, Noise=0.8695
# Iter 38: Loss=1.4320, Noise=0.8730
# Iter 39: Loss=1.4317, Noise=0.8766
# Iter 40: Loss=1.4314, Noise=0.8801
# Iter 41: Loss=1.4311, Noise=0.8834
# Iter 42: Loss=1.4307, Noise=0.8866
# Iter 43: Loss=1.4308, Noise=0.8897
# Iter 44: Loss=1.4306, Noise=0.8927
# Iter 45: Loss=1.4306, Noise=0.8956
# Iter 46: Loss=1.4302, Noise=0.8986
# Iter 47: Loss=1.4300, Noise=0.9015
# Iter 48: Loss=1.4300, Noise=0.9045
# Iter 49: Loss=1.4301, Noise=0.9074
# Iter 50: Loss=1.4298, Noise=0.9101
# Iter 51: Loss=1.4298, Noise=0.9127
# Iter 52: Loss=1.4295, Noise=0.9153
# Iter 53: Loss=1.4294, Noise=0.9177
# Iter 54: Loss=1.4294, Noise=0.9200
# Iter 55: Loss=1.4293, Noise=0.9222
# Iter 56: Loss=1.4294, Noise=0.9244
# Iter 57: Loss=1.4295, Noise=0.9266
# Iter 58: Loss=1.4294, Noise=0.9287
# Iter 59: Loss=1.4292, Noise=0.9308
# Iter 60: Loss=1.4291, Noise=0.9330
# Iter 61: Loss=1.4292, Noise=0.9349
# Iter 62: Loss=1.4290, Noise=0.9368
# Iter 63: Loss=1.4288, Noise=0.9386
# Iter 64: Loss=1.4289, Noise=0.9403
# Iter 65: Loss=1.4287, Noise=0.9421
# Iter 66: Loss=1.4288, Noise=0.9438
# Iter 67: Loss=1.4291, Noise=0.9455
# Iter 68: Loss=1.4285, Noise=0.9471
# Iter 69: Loss=1.4289, Noise=0.9487
# Iter 70: Loss=1.4289, Noise=0.9502
# Iter 71: Loss=1.4287, Noise=0.9517
# Iter 72: Loss=1.4290, Noise=0.9532
# Iter 73: Loss=1.4286, Noise=0.9546
# Iter 74: Loss=1.4286, Noise=0.9560
# Iter 75: Loss=1.4289, Noise=0.9573
# Iter 76: Loss=1.4289, Noise=0.9585
# Iter 77: Loss=1.4284, Noise=0.9598
# Iter 78: Loss=1.4288, Noise=0.9609
# Iter 79: Loss=1.4285, Noise=0.9619
# Iter 80: Loss=1.4285, Noise=0.9626
# Iter 81: Loss=1.4287, Noise=0.9632
# Iter 82: Loss=1.4287, Noise=0.9638
# Iter 83: Loss=1.4288, Noise=0.9642
# Iter 84: Loss=1.4283, Noise=0.9647
# Iter 85: Loss=1.4288, Noise=0.9652
# Iter 86: Loss=1.4288, Noise=0.9657
# Iter 87: Loss=1.4285, Noise=0.9662
# Iter 88: Loss=1.4285, Noise=0.9665
# Iter 89: Loss=1.4283, Noise=0.9670
# Iter 90: Loss=1.4284, Noise=0.9675
# Iter 91: Loss=1.4286, Noise=0.9681
# Iter 92: Loss=1.4284, Noise=0.9686
# Iter 93: Loss=1.4283, Noise=0.9691
# Iter 94: Loss=1.4286, Noise=0.9695
# Iter 95: Loss=1.4283, Noise=0.9700
# Iter 96: Loss=1.4287, Noise=0.9705
# Iter 97: Loss=1.4285, Noise=0.9710
# Iter 98: Loss=1.4282, Noise=0.9713
# Iter 99: Loss=1.4284, Noise=0.9715
# Iter 100: Loss=1.4284, Noise=0.9717
# Iter 101: Loss=1.4285, Noise=0.9720
# Iter 102: Loss=1.4287, Noise=0.9723
# Iter 103: Loss=1.4285, Noise=0.9725
# Iter 104: Loss=1.4286, Noise=0.9728
# Iter 105: Loss=1.4283, Noise=0.9732
# Iter 106: Loss=1.4280, Noise=0.9736
# Iter 107: Loss=1.4284, Noise=0.9740
# Iter 108: Loss=1.4283, Noise=0.9745
# Iter 109: Loss=1.4284, Noise=0.9749
# Iter 110: Loss=1.4282, Noise=0.9753
# Iter 111: Loss=1.4285, Noise=0.9756
# Iter 112: Loss=1.4281, Noise=0.9759
# Iter 113: Loss=1.4283, Noise=0.9761
# Iter 114: Loss=1.4280, Noise=0.9760
# Iter 115: Loss=1.4284, Noise=0.9758
# Iter 116: Loss=1.4282, Noise=0.9756
# Iter 117: Loss=1.4282, Noise=0.9756
# Iter 118: Loss=1.4280, Noise=0.9756
# Iter 119: Loss=1.4282, Noise=0.9756
# Iter 120: Loss=1.4280, Noise=0.9755
# Iter 121: Loss=1.4281, Noise=0.9753
# Iter 122: Loss=1.4279, Noise=0.9750
# Iter 123: Loss=1.4280, Noise=0.9747
# Iter 124: Loss=1.4279, Noise=0.9742
# Iter 125: Loss=1.4277, Noise=0.9738
# Iter 126: Loss=1.4279, Noise=0.9735
# Iter 127: Loss=1.4276, Noise=0.9731
# Iter 128: Loss=1.4274, Noise=0.9725
# Iter 129: Loss=1.4279, Noise=0.9719
# Iter 130: Loss=1.4277, Noise=0.9713
# Iter 131: Loss=1.4276, Noise=0.9707
# Iter 132: Loss=1.4276, Noise=0.9700
# Iter 133: Loss=1.4273, Noise=0.9693
# Iter 134: Loss=1.4272, Noise=0.9688
# Iter 135: Loss=1.4274, Noise=0.9685
# Iter 136: Loss=1.4273, Noise=0.9684
# Iter 137: Loss=1.4273, Noise=0.9684
# Iter 138: Loss=1.4273, Noise=0.9684
# Iter 139: Loss=1.4273, Noise=0.9683
# Iter 140: Loss=1.4271, Noise=0.9682
# Iter 141: Loss=1.4268, Noise=0.9682
# Iter 142: Loss=1.4268, Noise=0.9680
# Iter 143: Loss=1.4271, Noise=0.9679
# Iter 144: Loss=1.4271, Noise=0.9678
# Iter 145: Loss=1.4264, Noise=0.9676
# Iter 146: Loss=1.4266, Noise=0.9674
# Iter 147: Loss=1.4262, Noise=0.9674
# Iter 148: Loss=1.4267, Noise=0.9674
# Iter 149: Loss=1.4261, Noise=0.9675
# Iter 150: Loss=1.4264, Noise=0.9672
# Iter 151: Loss=1.4261, Noise=0.9668
# Iter 152: Loss=1.4261, Noise=0.9666
# Iter 153: Loss=1.4260, Noise=0.9663
# Iter 154: Loss=1.4256, Noise=0.9660
# Iter 155: Loss=1.4260, Noise=0.9655
# Iter 156: Loss=1.4257, Noise=0.9651
# Iter 157: Loss=1.4257, Noise=0.9648
# Iter 158: Loss=1.4255, Noise=0.9643
# Iter 159: Loss=1.4252, Noise=0.9641
# Iter 160: Loss=1.4252, Noise=0.9637
# Iter 161: Loss=1.4252, Noise=0.9632
# Iter 162: Loss=1.4246, Noise=0.9627
# Iter 163: Loss=1.4248, Noise=0.9621
# Iter 164: Loss=1.4249, Noise=0.9614
# Iter 165: Loss=1.4239, Noise=0.9607
# Iter 166: Loss=1.4242, Noise=0.9601
# Iter 167: Loss=1.4241, Noise=0.9595
# Iter 168: Loss=1.4243, Noise=0.9588
# Iter 169: Loss=1.4237, Noise=0.9581
# Iter 170: Loss=1.4234, Noise=0.9574
# Iter 171: Loss=1.4236, Noise=0.9567
# Iter 172: Loss=1.4230, Noise=0.9559
# Iter 173: Loss=1.4228, Noise=0.9551
# Iter 174: Loss=1.4229, Noise=0.9543
# Iter 175: Loss=1.4225, Noise=0.9535
# Iter 176: Loss=1.4223, Noise=0.9527
# Iter 177: Loss=1.4226, Noise=0.9521
# Iter 178: Loss=1.4222, Noise=0.9511
# Iter 179: Loss=1.4218, Noise=0.9502
# Iter 180: Loss=1.4214, Noise=0.9493
# Iter 181: Loss=1.4210, Noise=0.9480
# Iter 182: Loss=1.4211, Noise=0.9466
# Iter 183: Loss=1.4207, Noise=0.9454
# Iter 184: Loss=1.4209, Noise=0.9442
# Iter 185: Loss=1.4205, Noise=0.9430
# Iter 186: Loss=1.4199, Noise=0.9420
# Iter 187: Loss=1.4201, Noise=0.9408
# Iter 188: Loss=1.4199, Noise=0.9396
# Iter 189: Loss=1.4191, Noise=0.9383
# Iter 190: Loss=1.4184, Noise=0.9368
# Iter 191: Loss=1.4185, Noise=0.9352
# Iter 192: Loss=1.4181, Noise=0.9335
# Iter 193: Loss=1.4181, Noise=0.9321
# Iter 194: Loss=1.4180, Noise=0.9305
# Iter 195: Loss=1.4175, Noise=0.9291
# Iter 196: Loss=1.4161, Noise=0.9277
# Iter 197: Loss=1.4164, Noise=0.9263
# Iter 198: Loss=1.4159, Noise=0.9248
# Iter 199: Loss=1.4153, Noise=0.9232
# Iter 200: Loss=1.4153, Noise=0.9215
# Iter 201: Loss=1.4146, Noise=0.9196
# Iter 202: Loss=1.4146, Noise=0.9179
# Iter 203: Loss=1.4142, Noise=0.9159
# Iter 204: Loss=1.4135, Noise=0.9139
# Iter 205: Loss=1.4135, Noise=0.9122
# Iter 206: Loss=1.4121, Noise=0.9105
# Iter 207: Loss=1.4119, Noise=0.9086
# Iter 208: Loss=1.4120, Noise=0.9067
# Iter 209: Loss=1.4107, Noise=0.9045
# Iter 210: Loss=1.4103, Noise=0.9026
# Iter 211: Loss=1.4094, Noise=0.9010
# Iter 212: Loss=1.4093, Noise=0.8994
# Iter 213: Loss=1.4084, Noise=0.8978
# Iter 214: Loss=1.4077, Noise=0.8961
# Iter 215: Loss=1.4063, Noise=0.8945
# Iter 216: Loss=1.4066, Noise=0.8931
# Iter 217: Loss=1.4058, Noise=0.8915
# Iter 218: Loss=1.4056, Noise=0.8902
# Iter 219: Loss=1.4058, Noise=0.8885
# Iter 220: Loss=1.4049, Noise=0.8871
# Iter 221: Loss=1.4030, Noise=0.8855
# Iter 222: Loss=1.4033, Noise=0.8837
# Iter 223: Loss=1.4027, Noise=0.8821
# Iter 224: Loss=1.4022, Noise=0.8803
# Iter 225: Loss=1.4016, Noise=0.8786
# Iter 226: Loss=1.4003, Noise=0.8767
# Iter 227: Loss=1.3995, Noise=0.8747
# Iter 228: Loss=1.3990, Noise=0.8725
# Iter 229: Loss=1.3991, Noise=0.8701
# Iter 230: Loss=1.3981, Noise=0.8674
# Iter 231: Loss=1.3969, Noise=0.8644
# Iter 232: Loss=1.3968, Noise=0.8614
# Iter 233: Loss=1.3964, Noise=0.8584
# Iter 234: Loss=1.3953, Noise=0.8554
# Iter 235: Loss=1.3925, Noise=0.8520
# Iter 236: Loss=1.3931, Noise=0.8487
# Iter 237: Loss=1.3912, Noise=0.8453
# Iter 238: Loss=1.3921, Noise=0.8418
# Iter 239: Loss=1.3904, Noise=0.8382
# Iter 240: Loss=1.3860, Noise=0.8345
# Iter 241: Loss=1.3864, Noise=0.8307
# Iter 242: Loss=1.3869, Noise=0.8270
# Iter 243: Loss=1.3845, Noise=0.8234
# Iter 244: Loss=1.3837, Noise=0.8197
# Iter 245: Loss=1.3827, Noise=0.8161
# Iter 246: Loss=1.3823, Noise=0.8125
# Iter 247: Loss=1.3819, Noise=0.8089
# Iter 248: Loss=1.3817, Noise=0.8054
# Iter 249: Loss=1.3793, Noise=0.8018
# Iter 250: Loss=1.3783, Noise=0.7981
# Iter 251: Loss=1.3770, Noise=0.7944
# Iter 252: Loss=1.3747, Noise=0.7907
# Iter 253: Loss=1.3742, Noise=0.7869
# Iter 254: Loss=1.3741, Noise=0.7830
# Iter 255: Loss=1.3733, Noise=0.7789
# Iter 256: Loss=1.3707, Noise=0.7748
# Iter 257: Loss=1.3703, Noise=0.7705
# Iter 258: Loss=1.3695, Noise=0.7661
# Iter 259: Loss=1.3665, Noise=0.7618
# Iter 260: Loss=1.3660, Noise=0.7575
# Iter 261: Loss=1.3662, Noise=0.7532
# Iter 262: Loss=1.3617, Noise=0.7489
# Iter 263: Loss=1.3624, Noise=0.7446
# Iter 264: Loss=1.3605, Noise=0.7401
# Iter 265: Loss=1.3591, Noise=0.7358
# Iter 266: Loss=1.3574, Noise=0.7315
# Iter 267: Loss=1.3539, Noise=0.7270
# Iter 268: Loss=1.3536, Noise=0.7224
# Iter 269: Loss=1.3550, Noise=0.7178
# Iter 270: Loss=1.3501, Noise=0.7132
# Iter 271: Loss=1.3495, Noise=0.7086
# Iter 272: Loss=1.3475, Noise=0.7039
# Iter 273: Loss=1.3442, Noise=0.6990
# Iter 274: Loss=1.3457, Noise=0.6940
# Iter 275: Loss=1.3442, Noise=0.6890
# Iter 276: Loss=1.3401, Noise=0.6838
# Iter 277: Loss=1.3388, Noise=0.6786
# Iter 278: Loss=1.3363, Noise=0.6734
# Iter 279: Loss=1.3333, Noise=0.6680
# Iter 280: Loss=1.3333, Noise=0.6625
# Iter 281: Loss=1.3325, Noise=0.6571
# Iter 282: Loss=1.3298, Noise=0.6517
# Iter 283: Loss=1.3282, Noise=0.6464
# Iter 284: Loss=1.3267, Noise=0.6410
# Iter 285: Loss=1.3215, Noise=0.6356
# Iter 286: Loss=1.3212, Noise=0.6303
# Iter 287: Loss=1.3185, Noise=0.6249
# Iter 288: Loss=1.3187, Noise=0.6198
# Iter 289: Loss=1.3144, Noise=0.6145
# Iter 290: Loss=1.3130, Noise=0.6092
# Iter 291: Loss=1.3139, Noise=0.6037
# Iter 292: Loss=1.3130, Noise=0.5983
# Iter 293: Loss=1.3098, Noise=0.5928
# Iter 294: Loss=1.3097, Noise=0.5876
# Iter 295: Loss=1.3093, Noise=0.5821
# Iter 296: Loss=1.2980, Noise=0.5767
# Iter 297: Loss=1.2941, Noise=0.5713
# Iter 298: Loss=1.2988, Noise=0.5658
# Iter 299: Loss=1.2948, Noise=0.5602
# Iter 300: Loss=1.2920, Noise=0.5547
# Iter 301: Loss=1.2893, Noise=0.5492
# Iter 302: Loss=1.2862, Noise=0.5436
# Iter 303: Loss=1.2855, Noise=0.5381
# Iter 304: Loss=1.2802, Noise=0.5325
# Iter 305: Loss=1.2781, Noise=0.5269
# Iter 306: Loss=1.2769, Noise=0.5212
# Iter 307: Loss=1.2769, Noise=0.5156
# Iter 308: Loss=1.2700, Noise=0.5099
# Iter 309: Loss=1.2702, Noise=0.5040
# Iter 310: Loss=1.2677, Noise=0.4982
# Iter 311: Loss=1.2662, Noise=0.4924
# Iter 312: Loss=1.2619, Noise=0.4865
# Iter 313: Loss=1.2604, Noise=0.4808
# Iter 314: Loss=1.2562, Noise=0.4750
# Iter 315: Loss=1.2562, Noise=0.4692
# Iter 316: Loss=1.2460, Noise=0.4635
# Iter 317: Loss=1.2469, Noise=0.4578
# Iter 318: Loss=1.2452, Noise=0.4520
# Iter 319: Loss=1.2376, Noise=0.4463
# Iter 320: Loss=1.2391, Noise=0.4405
# Iter 321: Loss=1.2415, Noise=0.4347
# Iter 322: Loss=1.2329, Noise=0.4290
# Iter 323: Loss=1.2261, Noise=0.4231
# Iter 324: Loss=1.2252, Noise=0.4173
# Iter 325: Loss=1.2162, Noise=0.4115
# Iter 326: Loss=1.2155, Noise=0.4057
# Iter 327: Loss=1.2163, Noise=0.3999
# Iter 328: Loss=1.2087, Noise=0.3941
# Iter 329: Loss=1.1976, Noise=0.3883
# Iter 330: Loss=1.2006, Noise=0.3827
# Iter 331: Loss=1.2083, Noise=0.3773
# Iter 332: Loss=1.1924, Noise=0.3719
# Iter 333: Loss=1.1937, Noise=0.3666
# Iter 334: Loss=1.1873, Noise=0.3613
# Iter 335: Loss=1.1830, Noise=0.3559
# Iter 336: Loss=1.1854, Noise=0.3506
# Iter 337: Loss=1.1844, Noise=0.3452
# Iter 338: Loss=1.1753, Noise=0.3399
# Iter 339: Loss=1.1763, Noise=0.3346
# Iter 340: Loss=1.1677, Noise=0.3294
# Iter 341: Loss=1.1661, Noise=0.3242
# Iter 342: Loss=1.1652, Noise=0.3190
# Iter 343: Loss=1.1510, Noise=0.3140
# Iter 344: Loss=1.1463, Noise=0.3089
# Iter 345: Loss=1.1407, Noise=0.3039
# Iter 346: Loss=1.1493, Noise=0.2989
# Iter 347: Loss=1.1361, Noise=0.2940
# Iter 348: Loss=1.1375, Noise=0.2891
# Iter 349: Loss=1.1280, Noise=0.2843
# Iter 350: Loss=1.1296, Noise=0.2795
# Iter 351: Loss=1.1153, Noise=0.2748
# Iter 352: Loss=1.1194, Noise=0.2702
# Iter 353: Loss=1.1072, Noise=0.2656
# Iter 354: Loss=1.1055, Noise=0.2611
# Iter 355: Loss=1.0956, Noise=0.2567
# Iter 356: Loss=1.1080, Noise=0.2523
# Iter 357: Loss=1.1006, Noise=0.2480
# Iter 358: Loss=1.0941, Noise=0.2438
# Iter 359: Loss=1.0891, Noise=0.2397
# Iter 360: Loss=1.0759, Noise=0.2355
# Iter 361: Loss=1.0712, Noise=0.2314
# Iter 362: Loss=1.0635, Noise=0.2273
# Iter 363: Loss=1.0680, Noise=0.2233
# Iter 364: Loss=1.0632, Noise=0.2194
# Iter 365: Loss=1.0508, Noise=0.2154
# Iter 366: Loss=1.0616, Noise=0.2116
# Iter 367: Loss=1.0518, Noise=0.2078
# Iter 368: Loss=1.0522, Noise=0.2041
# Iter 369: Loss=1.0391, Noise=0.2005
# Iter 370: Loss=1.0355, Noise=0.1969
# Iter 371: Loss=1.0406, Noise=0.1934
# Iter 372: Loss=1.0287, Noise=0.1899
# Iter 373: Loss=1.0249, Noise=0.1865
# Iter 374: Loss=1.0268, Noise=0.1832
# Iter 375: Loss=1.0214, Noise=0.1798
# Iter 376: Loss=1.0049, Noise=0.1766
# Iter 377: Loss=1.0105, Noise=0.1733
# Iter 378: Loss=1.0078, Noise=0.1702
# Iter 379: Loss=0.9931, Noise=0.1671
# Iter 380: Loss=0.9985, Noise=0.1641
# Iter 381: Loss=0.9948, Noise=0.1611
# Iter 382: Loss=0.9880, Noise=0.1583
# Iter 383: Loss=0.9743, Noise=0.1555
# Iter 384: Loss=0.9780, Noise=0.1527
# Iter 385: Loss=0.9622, Noise=0.1500
# Iter 386: Loss=0.9781, Noise=0.1474
# Iter 387: Loss=0.9586, Noise=0.1448
# Iter 388: Loss=0.9559, Noise=0.1423
# Iter 389: Loss=0.9497, Noise=0.1398
# Iter 390: Loss=0.9381, Noise=0.1373
# Iter 391: Loss=0.9434, Noise=0.1349
# Iter 392: Loss=0.9271, Noise=0.1325
# Iter 393: Loss=0.9445, Noise=0.1302
# Iter 394: Loss=0.9268, Noise=0.1279
# Iter 395: Loss=0.9370, Noise=0.1257
# Iter 396: Loss=0.8937, Noise=0.1235
# Iter 397: Loss=0.9020, Noise=0.1213
# Iter 398: Loss=0.9179, Noise=0.1192
# Iter 399: Loss=0.9120, Noise=0.1171
# Iter 400: Loss=0.9041, Noise=0.1151
# Iter 401: Loss=0.9026, Noise=0.1131
# Iter 402: Loss=0.8925, Noise=0.1113
# Iter 403: Loss=0.8891, Noise=0.1094
# Iter 404: Loss=0.8930, Noise=0.1075
# Iter 405: Loss=0.8985, Noise=0.1057
# Iter 406: Loss=0.8851, Noise=0.1040
# Iter 407: Loss=0.8767, Noise=0.1023
# Iter 408: Loss=0.8588, Noise=0.1006
# Iter 409: Loss=0.8869, Noise=0.0989
# Iter 410: Loss=0.8697, Noise=0.0973
# Iter 411: Loss=0.8715, Noise=0.0958
# Iter 412: Loss=0.8694, Noise=0.0943
# Iter 413: Loss=0.8728, Noise=0.0928
# Iter 414: Loss=0.8618, Noise=0.0913
# Iter 415: Loss=0.8589, Noise=0.0899
# Iter 416: Loss=0.8375, Noise=0.0885
# Iter 417: Loss=0.8532, Noise=0.0871
# Iter 418: Loss=0.8425, Noise=0.0858
# Iter 419: Loss=0.8612, Noise=0.0845
# Iter 420: Loss=0.8295, Noise=0.0832
# Iter 421: Loss=0.8365, Noise=0.0819
# Iter 422: Loss=0.8241, Noise=0.0807
# Iter 423: Loss=0.8202, Noise=0.0795
# Iter 424: Loss=0.8228, Noise=0.0783
# Iter 425: Loss=0.8154, Noise=0.0772
# Iter 426: Loss=0.8254, Noise=0.0761
# Iter 427: Loss=0.8206, Noise=0.0749
# Iter 428: Loss=0.8258, Noise=0.0739
# Iter 429: Loss=0.7996, Noise=0.0728
# Iter 430: Loss=0.7787, Noise=0.0718
# Iter 431: Loss=0.7829, Noise=0.0707
# Iter 432: Loss=0.7914, Noise=0.0697
# Iter 433: Loss=0.7667, Noise=0.0687
# Iter 434: Loss=0.7848, Noise=0.0677
# Iter 435: Loss=0.7858, Noise=0.0667
# Iter 436: Loss=0.7836, Noise=0.0658
# Iter 437: Loss=0.7624, Noise=0.0648
# Iter 438: Loss=0.7901, Noise=0.0639
# Iter 439: Loss=0.7672, Noise=0.0630
# Iter 440: Loss=0.7525, Noise=0.0622
# Iter 441: Loss=0.7816, Noise=0.0613
# Iter 442: Loss=0.7456, Noise=0.0605
# Iter 443: Loss=0.7449, Noise=0.0597
# Iter 444: Loss=0.7536, Noise=0.0588
# Iter 445: Loss=0.7666, Noise=0.0580
# Iter 446: Loss=0.7703, Noise=0.0572
# Iter 447: Loss=0.7619, Noise=0.0565
# Iter 448: Loss=0.7507, Noise=0.0557
# Iter 449: Loss=0.7313, Noise=0.0550
# Iter 450: Loss=0.7354, Noise=0.0543
# Iter 451: Loss=0.7093, Noise=0.0536
# Iter 452: Loss=0.7373, Noise=0.0529
# Iter 453: Loss=0.7478, Noise=0.0522
# Iter 454: Loss=0.7104, Noise=0.0515
# Iter 455: Loss=0.7453, Noise=0.0509
# Iter 456: Loss=0.7184, Noise=0.0502
# Iter 457: Loss=0.7093, Noise=0.0496
# Iter 458: Loss=0.7055, Noise=0.0490
# Iter 459: Loss=0.6889, Noise=0.0484
# Iter 460: Loss=0.7166, Noise=0.0478
# Iter 461: Loss=0.7048, Noise=0.0472
# Iter 462: Loss=0.7131, Noise=0.0466
# Iter 463: Loss=0.6953, Noise=0.0460
# Iter 464: Loss=0.7253, Noise=0.0455
# Iter 465: Loss=0.7192, Noise=0.0449
# Iter 466: Loss=0.6982, Noise=0.0444
# Iter 467: Loss=0.6868, Noise=0.0438
# Iter 468: Loss=0.6968, Noise=0.0433
# Iter 469: Loss=0.7079, Noise=0.0428
# Iter 470: Loss=0.6471, Noise=0.0423
# Iter 471: Loss=0.6836, Noise=0.0418
# Iter 472: Loss=0.7049, Noise=0.0413
# Iter 473: Loss=0.6410, Noise=0.0408
# Iter 474: Loss=0.6784, Noise=0.0403
# Iter 475: Loss=0.6943, Noise=0.0398
# Iter 476: Loss=0.6646, Noise=0.0394
# Iter 477: Loss=0.6339, Noise=0.0389
# Iter 478: Loss=0.6752, Noise=0.0385
# Iter 479: Loss=0.6788, Noise=0.0380
# Iter 480: Loss=0.6647, Noise=0.0376
# Iter 481: Loss=0.6417, Noise=0.0371
# Iter 482: Loss=0.6307, Noise=0.0367
# Iter 483: Loss=0.6724, Noise=0.0363
# Iter 484: Loss=0.6697, Noise=0.0359
# Iter 485: Loss=0.6904, Noise=0.0355
# Iter 486: Loss=0.6433, Noise=0.0351
# Iter 487: Loss=0.6461, Noise=0.0347
# Iter 488: Loss=0.6522, Noise=0.0343
# Iter 489: Loss=0.6363, Noise=0.0340
# Iter 490: Loss=0.6407, Noise=0.0336
# Iter 491: Loss=0.6291, Noise=0.0332
# Iter 492: Loss=0.6267, Noise=0.0329
# Iter 493: Loss=0.6200, Noise=0.0325
# Iter 494: Loss=0.6468, Noise=0.0322
# Iter 495: Loss=0.6053, Noise=0.0318
# Iter 496: Loss=0.6335, Noise=0.0315
# Iter 497: Loss=0.6345, Noise=0.0312
# Iter 498: Loss=0.6487, Noise=0.0309
# Iter 499: Loss=0.6062, Noise=0.0305
# Iter 500: Loss=0.6292, Noise=0.0302
# Iter 501: Loss=0.6371, Noise=0.0299
# Iter 502: Loss=0.6355, Noise=0.0296
# Iter 503: Loss=0.6257, Noise=0.0294
# Iter 504: Loss=0.6115, Noise=0.0291
# Iter 505: Loss=0.6260, Noise=0.0288
# Iter 506: Loss=0.6132, Noise=0.0285
# Iter 507: Loss=0.6316, Noise=0.0282
# Iter 508: Loss=0.6106, Noise=0.0280
# Iter 509: Loss=0.5918, Noise=0.0277
# Iter 510: Loss=0.6014, Noise=0.0274
# Iter 511: Loss=0.6175, Noise=0.0271
# Iter 512: Loss=0.6098, Noise=0.0269
# Iter 513: Loss=0.5912, Noise=0.0266
# Iter 514: Loss=0.5911, Noise=0.0264
# Iter 515: Loss=0.5901, Noise=0.0261
# Iter 516: Loss=0.5937, Noise=0.0259
# Iter 517: Loss=0.6170, Noise=0.0256
# Iter 518: Loss=0.5853, Noise=0.0254
# Iter 519: Loss=0.6088, Noise=0.0252
# Iter 520: Loss=0.5565, Noise=0.0249
# Iter 521: Loss=0.5768, Noise=0.0247
# Iter 522: Loss=0.6044, Noise=0.0245
# Iter 523: Loss=0.5865, Noise=0.0243
# Iter 524: Loss=0.5834, Noise=0.0241
# Iter 525: Loss=0.5718, Noise=0.0238
# Iter 526: Loss=0.5478, Noise=0.0236
# Iter 527: Loss=0.5572, Noise=0.0234
# Iter 528: Loss=0.5871, Noise=0.0232
# Iter 529: Loss=0.5518, Noise=0.0230
# Iter 530: Loss=0.5712, Noise=0.0228
# Iter 531: Loss=0.5739, Noise=0.0226
# Iter 532: Loss=0.5766, Noise=0.0224
# Iter 533: Loss=0.5912, Noise=0.0222
# Iter 534: Loss=0.5779, Noise=0.0221
# Iter 535: Loss=0.5746, Noise=0.0219
# Iter 536: Loss=0.5495, Noise=0.0217
# Iter 537: Loss=0.5584, Noise=0.0215
# Iter 538: Loss=0.5810, Noise=0.0213
# Iter 539: Loss=0.5437, Noise=0.0212
# Iter 540: Loss=0.5543, Noise=0.0210
# Iter 541: Loss=0.5489, Noise=0.0208
# Iter 542: Loss=0.5472, Noise=0.0206
# Iter 543: Loss=0.5754, Noise=0.0205
# Iter 544: Loss=0.5416, Noise=0.0203
# Iter 545: Loss=0.5440, Noise=0.0201
# Iter 546: Loss=0.5406, Noise=0.0200
# Iter 547: Loss=0.5484, Noise=0.0198
# Iter 548: Loss=0.5537, Noise=0.0197
# Iter 549: Loss=0.5472, Noise=0.0195
# Iter 550: Loss=0.5043, Noise=0.0194
# Iter 551: Loss=0.5176, Noise=0.0192
# Iter 552: Loss=0.5538, Noise=0.0190
# Iter 553: Loss=0.4980, Noise=0.0189
# Iter 554: Loss=0.5623, Noise=0.0187
# Iter 555: Loss=0.5392, Noise=0.0186
# Iter 556: Loss=0.5243, Noise=0.0185
# Iter 557: Loss=0.5284, Noise=0.0183
# Iter 558: Loss=0.5548, Noise=0.0182
# Iter 559: Loss=0.5220, Noise=0.0180
# Iter 560: Loss=0.5182, Noise=0.0179
# Iter 561: Loss=0.5118, Noise=0.0178
# Iter 562: Loss=0.5037, Noise=0.0176
# Iter 563: Loss=0.5343, Noise=0.0175
# Iter 564: Loss=0.5415, Noise=0.0174
# Iter 565: Loss=0.5268, Noise=0.0173
# Iter 566: Loss=0.5102, Noise=0.0171
# Iter 567: Loss=0.5332, Noise=0.0170
# Iter 568: Loss=0.5132, Noise=0.0169
# Iter 569: Loss=0.4862, Noise=0.0168
# Iter 570: Loss=0.5328, Noise=0.0167
# Iter 571: Loss=0.5079, Noise=0.0165
# Iter 572: Loss=0.5277, Noise=0.0164
# Iter 573: Loss=0.4775, Noise=0.0163
# Iter 574: Loss=0.4991, Noise=0.0162
# Iter 575: Loss=0.5198, Noise=0.0161
# Iter 576: Loss=0.4846, Noise=0.0160
# Iter 577: Loss=0.5113, Noise=0.0159
# Iter 578: Loss=0.4989, Noise=0.0158
# Iter 579: Loss=0.5023, Noise=0.0157
# Iter 580: Loss=0.5147, Noise=0.0156
# Iter 581: Loss=0.5385, Noise=0.0155
# Iter 582: Loss=0.5301, Noise=0.0154
# Iter 583: Loss=0.5057, Noise=0.0153
# Iter 584: Loss=0.4732, Noise=0.0152
# Iter 585: Loss=0.4964, Noise=0.0151
# Iter 586: Loss=0.4609, Noise=0.0150
# Iter 587: Loss=0.4971, Noise=0.0149
# Iter 588: Loss=0.4749, Noise=0.0148
# Iter 589: Loss=0.4730, Noise=0.0147
# Iter 590: Loss=0.5263, Noise=0.0146
# Iter 591: Loss=0.5100, Noise=0.0145
# Iter 592: Loss=0.4613, Noise=0.0145
# Iter 593: Loss=0.4718, Noise=0.0144
# Iter 594: Loss=0.4899, Noise=0.0143
# Iter 595: Loss=0.5030, Noise=0.0142
# Iter 596: Loss=0.4838, Noise=0.0141
# Iter 597: Loss=0.5083, Noise=0.0140
# Iter 598: Loss=0.4653, Noise=0.0140
# Iter 599: Loss=0.4787, Noise=0.0139
# Iter 600: Loss=0.4688, Noise=0.0138
# Iter 601: Loss=0.4753, Noise=0.0137
# Iter 602: Loss=0.4742, Noise=0.0137
# Iter 603: Loss=0.4885, Noise=0.0136
# Iter 604: Loss=0.4414, Noise=0.0135
# Iter 605: Loss=0.4863, Noise=0.0134
# Iter 606: Loss=0.4920, Noise=0.0134
# Iter 607: Loss=0.4814, Noise=0.0133
# Iter 608: Loss=0.4457, Noise=0.0132
# Iter 609: Loss=0.4412, Noise=0.0131
# Iter 610: Loss=0.4765, Noise=0.0131
# Iter 611: Loss=0.4789, Noise=0.0130
# Iter 612: Loss=0.4694, Noise=0.0129
# Iter 613: Loss=0.4882, Noise=0.0129
# Iter 614: Loss=0.4715, Noise=0.0128
# Iter 615: Loss=0.4815, Noise=0.0127
# Iter 616: Loss=0.4560, Noise=0.0127
# Iter 617: Loss=0.4606, Noise=0.0126
# Iter 618: Loss=0.4409, Noise=0.0126
# Iter 619: Loss=0.4505, Noise=0.0125
# Iter 620: Loss=0.4756, Noise=0.0124
# Iter 621: Loss=0.4559, Noise=0.0124
# Iter 622: Loss=0.4689, Noise=0.0123
# Iter 623: Loss=0.4455, Noise=0.0123
# Iter 624: Loss=0.4673, Noise=0.0122
# Iter 625: Loss=0.4174, Noise=0.0121
# Iter 626: Loss=0.4225, Noise=0.0121
# Iter 627: Loss=0.4630, Noise=0.0120
# Iter 628: Loss=0.4237, Noise=0.0120
# Iter 629: Loss=0.4227, Noise=0.0119
# Iter 630: Loss=0.4588, Noise=0.0118
# Iter 631: Loss=0.4014, Noise=0.0118
# Iter 632: Loss=0.4356, Noise=0.0117
# Iter 633: Loss=0.4853, Noise=0.0117
# Iter 634: Loss=0.4427, Noise=0.0116
# Iter 635: Loss=0.4425, Noise=0.0116
# Iter 636: Loss=0.4524, Noise=0.0115
# Iter 637: Loss=0.4475, Noise=0.0115
# Iter 638: Loss=0.4192, Noise=0.0114
# Iter 639: Loss=0.4086, Noise=0.0114
# Iter 640: Loss=0.4266, Noise=0.0113
# Iter 641: Loss=0.4733, Noise=0.0113
# Iter 642: Loss=0.4502, Noise=0.0112
# Iter 643: Loss=0.4201, Noise=0.0112
# Iter 644: Loss=0.4578, Noise=0.0111
# Iter 645: Loss=0.4045, Noise=0.0111
# Iter 646: Loss=0.4494, Noise=0.0110
# Iter 647: Loss=0.4630, Noise=0.0110
# Iter 648: Loss=0.4217, Noise=0.0109
# Iter 649: Loss=0.4183, Noise=0.0109
# Iter 650: Loss=0.4020, Noise=0.0108
# Iter 651: Loss=0.4438, Noise=0.0108
# Iter 652: Loss=0.4311, Noise=0.0107
# Iter 653: Loss=0.4186, Noise=0.0107
# Iter 654: Loss=0.4079, Noise=0.0107
# Iter 655: Loss=0.3840, Noise=0.0106
# Iter 656: Loss=0.4245, Noise=0.0106
# Iter 657: Loss=0.4190, Noise=0.0105
# Iter 658: Loss=0.4741, Noise=0.0105
# Iter 659: Loss=0.3886, Noise=0.0104
# Iter 660: Loss=0.4345, Noise=0.0104
# Iter 661: Loss=0.4523, Noise=0.0104
# Iter 662: Loss=0.3912, Noise=0.0103
# Iter 663: Loss=0.4117, Noise=0.0103
# Iter 664: Loss=0.4232, Noise=0.0103
# Iter 665: Loss=0.4133, Noise=0.0102
# Iter 666: Loss=0.4013, Noise=0.0102
# Iter 667: Loss=0.4230, Noise=0.0101
# Iter 668: Loss=0.4202, Noise=0.0101
# Iter 669: Loss=0.3847, Noise=0.0101
# Iter 670: Loss=0.4256, Noise=0.0100
# Iter 671: Loss=0.4155, Noise=0.0100
# Iter 672: Loss=0.3668, Noise=0.0100
# Iter 673: Loss=0.4110, Noise=0.0099
# Iter 674: Loss=0.4107, Noise=0.0099
# Iter 675: Loss=0.3973, Noise=0.0099
# Iter 676: Loss=0.4064, Noise=0.0098
# Iter 677: Loss=0.4329, Noise=0.0098
# Iter 678: Loss=0.4148, Noise=0.0098
# Iter 679: Loss=0.4125, Noise=0.0097
# Iter 680: Loss=0.3883, Noise=0.0097
# Iter 681: Loss=0.4121, Noise=0.0097
# Iter 682: Loss=0.4179, Noise=0.0096
# Iter 683: Loss=0.4485, Noise=0.0096
# Iter 684: Loss=0.4159, Noise=0.0096
# Iter 685: Loss=0.4319, Noise=0.0096
# Iter 686: Loss=0.3943, Noise=0.0095
# Iter 687: Loss=0.4362, Noise=0.0095
# Iter 688: Loss=0.3719, Noise=0.0095
# Iter 689: Loss=0.3984, Noise=0.0094
# Iter 690: Loss=0.4261, Noise=0.0094
# Iter 691: Loss=0.4059, Noise=0.0094
# Iter 692: Loss=0.3949, Noise=0.0094
# Iter 693: Loss=0.3746, Noise=0.0093
# Iter 694: Loss=0.3958, Noise=0.0093
# Iter 695: Loss=0.4249, Noise=0.0093
# Iter 696: Loss=0.3949, Noise=0.0092
# Iter 697: Loss=0.3949, Noise=0.0092
# Iter 698: Loss=0.3866, Noise=0.0092
# Iter 699: Loss=0.3870, Noise=0.0092
# Iter 700: Loss=0.3977, Noise=0.0091
# Iter 701: Loss=0.3624, Noise=0.0091
# Iter 702: Loss=0.3890, Noise=0.0091
# Iter 703: Loss=0.3981, Noise=0.0091
# Iter 704: Loss=0.3933, Noise=0.0090
# Iter 705: Loss=0.3681, Noise=0.0090
# Iter 706: Loss=0.3862, Noise=0.0090
# Iter 707: Loss=0.3928, Noise=0.0090
# Iter 708: Loss=0.3758, Noise=0.0089
# Iter 709: Loss=0.3571, Noise=0.0089
# Iter 710: Loss=0.3494, Noise=0.0089
# Iter 711: Loss=0.4096, Noise=0.0089
# Iter 712: Loss=0.3800, Noise=0.0088
# Iter 713: Loss=0.3856, Noise=0.0088
# Iter 714: Loss=0.3888, Noise=0.0088
# Iter 715: Loss=0.3622, Noise=0.0088
# Iter 716: Loss=0.3661, Noise=0.0088
# Iter 717: Loss=0.3882, Noise=0.0087
# Iter 718: Loss=0.3801, Noise=0.0087
# Iter 719: Loss=0.3620, Noise=0.0087
# Iter 720: Loss=0.3999, Noise=0.0087
# Iter 721: Loss=0.3721, Noise=0.0087
# Iter 722: Loss=0.3890, Noise=0.0086
# Iter 723: Loss=0.3976, Noise=0.0086
# Iter 724: Loss=0.3808, Noise=0.0086
# Iter 725: Loss=0.3900, Noise=0.0086
# Iter 726: Loss=0.3601, Noise=0.0086
# Iter 727: Loss=0.3887, Noise=0.0085
# Iter 728: Loss=0.3830, Noise=0.0085
# Iter 729: Loss=0.3987, Noise=0.0085
# Iter 730: Loss=0.3748, Noise=0.0085
# Iter 731: Loss=0.3679, Noise=0.0085
# Iter 732: Loss=0.3725, Noise=0.0084
# Iter 733: Loss=0.3542, Noise=0.0084
# Iter 734: Loss=0.3868, Noise=0.0084
# Iter 735: Loss=0.3416, Noise=0.0084
# Iter 736: Loss=0.3846, Noise=0.0084
# Iter 737: Loss=0.3750, Noise=0.0084
# Iter 738: Loss=0.3879, Noise=0.0083
# Iter 739: Loss=0.3902, Noise=0.0083
# Iter 740: Loss=0.3440, Noise=0.0083
# Iter 741: Loss=0.3544, Noise=0.0083
# Iter 742: Loss=0.3574, Noise=0.0083
# Iter 743: Loss=0.4130, Noise=0.0083
# Iter 744: Loss=0.3733, Noise=0.0083
# Iter 745: Loss=0.3846, Noise=0.0082
# Iter 746: Loss=0.3387, Noise=0.0082
# Iter 747: Loss=0.3421, Noise=0.0082
# Iter 748: Loss=0.3892, Noise=0.0082
# Iter 749: Loss=0.3492, Noise=0.0082
# Iter 750: Loss=0.3352, Noise=0.0082
# Iter 751: Loss=0.3452, Noise=0.0081
# Iter 752: Loss=0.3408, Noise=0.0081
# Iter 753: Loss=0.3678, Noise=0.0081
# Iter 754: Loss=0.3275, Noise=0.0081
# Iter 755: Loss=0.3598, Noise=0.0081
# Iter 756: Loss=0.3513, Noise=0.0081
# Iter 757: Loss=0.3736, Noise=0.0081
# Iter 758: Loss=0.3737, Noise=0.0080
# Iter 759: Loss=0.3516, Noise=0.0080
# Iter 760: Loss=0.3516, Noise=0.0080
# Iter 761: Loss=0.3459, Noise=0.0080
# Iter 762: Loss=0.3452, Noise=0.0080
# Iter 763: Loss=0.3406, Noise=0.0080
# Iter 764: Loss=0.3612, Noise=0.0080
# Iter 765: Loss=0.3798, Noise=0.0079
# Iter 766: Loss=0.3527, Noise=0.0079
# Iter 767: Loss=0.3707, Noise=0.0079
# Iter 768: Loss=0.3361, Noise=0.0079
# Iter 769: Loss=0.3712, Noise=0.0079
# Iter 770: Loss=0.3506, Noise=0.0079
# Iter 771: Loss=0.3363, Noise=0.0079
# Iter 772: Loss=0.3564, Noise=0.0079
# Iter 773: Loss=0.3551, Noise=0.0079
# Iter 774: Loss=0.3485, Noise=0.0078
# Iter 775: Loss=0.3893, Noise=0.0078
# Iter 776: Loss=0.3470, Noise=0.0078
# Iter 777: Loss=0.3466, Noise=0.0078
# Iter 778: Loss=0.3676, Noise=0.0078
# Iter 779: Loss=0.3484, Noise=0.0078
# Iter 780: Loss=0.3045, Noise=0.0078
# Iter 781: Loss=0.3389, Noise=0.0078
# Iter 782: Loss=0.3146, Noise=0.0078
# Iter 783: Loss=0.3651, Noise=0.0078
# Iter 784: Loss=0.3295, Noise=0.0077
# Iter 785: Loss=0.3242, Noise=0.0077
# Iter 786: Loss=0.3571, Noise=0.0077
# Iter 787: Loss=0.3412, Noise=0.0077
# Iter 788: Loss=0.3170, Noise=0.0077
# Iter 789: Loss=0.3115, Noise=0.0077
# Iter 790: Loss=0.3352, Noise=0.0077
# Iter 791: Loss=0.3468, Noise=0.0077
# Iter 792: Loss=0.3112, Noise=0.0076
# Iter 793: Loss=0.3328, Noise=0.0076
# Iter 794: Loss=0.3281, Noise=0.0076
# Iter 795: Loss=0.3443, Noise=0.0076
# Iter 796: Loss=0.3394, Noise=0.0076
# Iter 797: Loss=0.3487, Noise=0.0076
# Iter 798: Loss=0.3096, Noise=0.0076
# Iter 799: Loss=0.3397, Noise=0.0076
# Iter 800: Loss=0.3058, Noise=0.0076
# Iter 801: Loss=0.3098, Noise=0.0075
# Iter 802: Loss=0.3673, Noise=0.0075
# Iter 803: Loss=0.3375, Noise=0.0075
# Iter 804: Loss=0.3333, Noise=0.0075
# Iter 805: Loss=0.3219, Noise=0.0075
# Iter 806: Loss=0.3409, Noise=0.0075
# Iter 807: Loss=0.3261, Noise=0.0075
# Iter 808: Loss=0.2647, Noise=0.0075
# Iter 809: Loss=0.3346, Noise=0.0075
# Iter 810: Loss=0.3270, Noise=0.0075
# Iter 811: Loss=0.3422, Noise=0.0075
# Iter 812: Loss=0.3531, Noise=0.0074
# Iter 813: Loss=0.3557, Noise=0.0074
# Iter 814: Loss=0.3089, Noise=0.0074
# Iter 815: Loss=0.2859, Noise=0.0074
# Iter 816: Loss=0.2968, Noise=0.0074
# Iter 817: Loss=0.3107, Noise=0.0074
# Iter 818: Loss=0.3229, Noise=0.0074
# Iter 819: Loss=0.2859, Noise=0.0074
# Iter 820: Loss=0.3132, Noise=0.0074
# Iter 821: Loss=0.3164, Noise=0.0074
# Iter 822: Loss=0.3325, Noise=0.0074
# Iter 823: Loss=0.3341, Noise=0.0074
# Iter 824: Loss=0.3333, Noise=0.0074
# Iter 825: Loss=0.3559, Noise=0.0073
# Iter 826: Loss=0.2801, Noise=0.0073
# Iter 827: Loss=0.3343, Noise=0.0073
# Iter 828: Loss=0.3355, Noise=0.0073
# Iter 829: Loss=0.3553, Noise=0.0073
# Iter 830: Loss=0.3180, Noise=0.0073
# Iter 831: Loss=0.2930, Noise=0.0073
# Iter 832: Loss=0.2877, Noise=0.0073
# Iter 833: Loss=0.3099, Noise=0.0073
# Iter 834: Loss=0.3229, Noise=0.0073
# Iter 835: Loss=0.3751, Noise=0.0073
# Iter 836: Loss=0.3183, Noise=0.0073
# Iter 837: Loss=0.3147, Noise=0.0073
# Iter 838: Loss=0.3180, Noise=0.0073
# Iter 839: Loss=0.3479, Noise=0.0073
# Iter 840: Loss=0.3237, Noise=0.0073
# Iter 841: Loss=0.3032, Noise=0.0073
# Iter 842: Loss=0.3240, Noise=0.0073
# Iter 843: Loss=0.3086, Noise=0.0072
# Iter 844: Loss=0.3415, Noise=0.0072
# Iter 845: Loss=0.3457, Noise=0.0072
# Iter 846: Loss=0.2834, Noise=0.0072
# Iter 847: Loss=0.3318, Noise=0.0072
# Iter 848: Loss=0.3069, Noise=0.0072
# Iter 849: Loss=0.3535, Noise=0.0072
# Iter 850: Loss=0.3167, Noise=0.0072
# Iter 851: Loss=0.3053, Noise=0.0072
# Iter 852: Loss=0.2812, Noise=0.0072
# Iter 853: Loss=0.3304, Noise=0.0072
# Iter 854: Loss=0.3214, Noise=0.0072
# Iter 855: Loss=0.2845, Noise=0.0072
# Iter 856: Loss=0.2743, Noise=0.0072
# Iter 857: Loss=0.3290, Noise=0.0072
# Iter 858: Loss=0.3159, Noise=0.0072
# Iter 859: Loss=0.2862, Noise=0.0072
# Iter 860: Loss=0.3233, Noise=0.0072
# Iter 861: Loss=0.3110, Noise=0.0072
# Iter 862: Loss=0.3265, Noise=0.0072
# Iter 863: Loss=0.3146, Noise=0.0072
# Iter 864: Loss=0.3362, Noise=0.0072
# Iter 865: Loss=0.3285, Noise=0.0072
# Iter 866: Loss=0.3381, Noise=0.0072
# Iter 867: Loss=0.3212, Noise=0.0072
# Iter 868: Loss=0.3173, Noise=0.0071
# Iter 869: Loss=0.2968, Noise=0.0071
# Iter 870: Loss=0.3012, Noise=0.0071
# Iter 871: Loss=0.2723, Noise=0.0071
# Iter 872: Loss=0.2967, Noise=0.0071
# Iter 873: Loss=0.2965, Noise=0.0071
# Iter 874: Loss=0.2977, Noise=0.0071
# Iter 875: Loss=0.3215, Noise=0.0071
# Iter 876: Loss=0.2441, Noise=0.0071
# Iter 877: Loss=0.3464, Noise=0.0071
# Iter 878: Loss=0.3328, Noise=0.0071
# Iter 879: Loss=0.3368, Noise=0.0071
# Iter 880: Loss=0.2935, Noise=0.0071
# Iter 881: Loss=0.3241, Noise=0.0071
# Iter 882: Loss=0.3308, Noise=0.0071
# Iter 883: Loss=0.3154, Noise=0.0071
# Iter 884: Loss=0.3045, Noise=0.0071
# Iter 885: Loss=0.3147, Noise=0.0071
# Iter 886: Loss=0.3014, Noise=0.0071
# Iter 887: Loss=0.2773, Noise=0.0071
# Iter 888: Loss=0.3081, Noise=0.0071
# Iter 889: Loss=0.3051, Noise=0.0071
# Iter 890: Loss=0.3198, Noise=0.0071
# Iter 891: Loss=0.2640, Noise=0.0071
# Iter 892: Loss=0.3069, Noise=0.0070
# Iter 893: Loss=0.2810, Noise=0.0070
# Iter 894: Loss=0.2964, Noise=0.0070
# Iter 895: Loss=0.3015, Noise=0.0070
# Iter 896: Loss=0.3162, Noise=0.0070
# Iter 897: Loss=0.3346, Noise=0.0070
# Iter 898: Loss=0.3304, Noise=0.0070
# Iter 899: Loss=0.2954, Noise=0.0070
# Iter 900: Loss=0.2974, Noise=0.0070
# Iter 901: Loss=0.3302, Noise=0.0070
# Iter 902: Loss=0.2850, Noise=0.0070
# Iter 903: Loss=0.2566, Noise=0.0070
# Iter 904: Loss=0.2981, Noise=0.0070
# Iter 905: Loss=0.2785, Noise=0.0070
# Iter 906: Loss=0.2992, Noise=0.0070
# Iter 907: Loss=0.2669, Noise=0.0070
# Iter 908: Loss=0.3010, Noise=0.0070
# Iter 909: Loss=0.3045, Noise=0.0070
# Iter 910: Loss=0.2767, Noise=0.0070
# Iter 911: Loss=0.2818, Noise=0.0070
# Iter 912: Loss=0.2494, Noise=0.0070
# Iter 913: Loss=0.2693, Noise=0.0070
# Iter 914: Loss=0.3026, Noise=0.0070
# Iter 915: Loss=0.3035, Noise=0.0070
# Iter 916: Loss=0.3187, Noise=0.0069
# Iter 917: Loss=0.3060, Noise=0.0069
# Iter 918: Loss=0.2746, Noise=0.0069
# Iter 919: Loss=0.2915, Noise=0.0069
# Iter 920: Loss=0.3056, Noise=0.0069
# Iter 921: Loss=0.3006, Noise=0.0069
# Iter 922: Loss=0.2771, Noise=0.0069
# Iter 923: Loss=0.2909, Noise=0.0069
# Iter 924: Loss=0.2895, Noise=0.0069
# Iter 925: Loss=0.3229, Noise=0.0069
# Iter 926: Loss=0.2950, Noise=0.0069
# Iter 927: Loss=0.2773, Noise=0.0069
# Iter 928: Loss=0.2914, Noise=0.0069
# Iter 929: Loss=0.3101, Noise=0.0069
# Iter 930: Loss=0.3202, Noise=0.0069
# Iter 931: Loss=0.2933, Noise=0.0069
# Iter 932: Loss=0.3314, Noise=0.0069
# Iter 933: Loss=0.2874, Noise=0.0069
# Iter 934: Loss=0.3178, Noise=0.0069
# Iter 935: Loss=0.3051, Noise=0.0069
# Iter 936: Loss=0.3162, Noise=0.0069
# Iter 937: Loss=0.2740, Noise=0.0069
# Iter 938: Loss=0.3202, Noise=0.0069
# Iter 939: Loss=0.3081, Noise=0.0069
# Iter 940: Loss=0.2592, Noise=0.0069
# Iter 941: Loss=0.2610, Noise=0.0069
# Iter 942: Loss=0.2842, Noise=0.0069
# Iter 943: Loss=0.2868, Noise=0.0069
# Iter 944: Loss=0.3304, Noise=0.0069
# Iter 945: Loss=0.3001, Noise=0.0069
# Iter 946: Loss=0.2440, Noise=0.0069
# Iter 947: Loss=0.3413, Noise=0.0069
# Iter 948: Loss=0.2889, Noise=0.0069
# Iter 949: Loss=0.2836, Noise=0.0069
# Iter 950: Loss=0.3177, Noise=0.0069
# Iter 951: Loss=0.2836, Noise=0.0069
# Iter 952: Loss=0.2936, Noise=0.0069
# Iter 953: Loss=0.3100, Noise=0.0069
# Iter 954: Loss=0.2859, Noise=0.0069
# Iter 955: Loss=0.2570, Noise=0.0069
# Iter 956: Loss=0.2803, Noise=0.0069
# Iter 957: Loss=0.2955, Noise=0.0069
# Iter 958: Loss=0.2600, Noise=0.0069
# Iter 959: Loss=0.2955, Noise=0.0069
# Iter 960: Loss=0.2526, Noise=0.0069
# Iter 961: Loss=0.3059, Noise=0.0069
# Iter 962: Loss=0.2573, Noise=0.0069
# Iter 963: Loss=0.2738, Noise=0.0069
# Iter 964: Loss=0.2746, Noise=0.0069
# Iter 965: Loss=0.2648, Noise=0.0069
# Iter 966: Loss=0.2874, Noise=0.0069
# Iter 967: Loss=0.2804, Noise=0.0069
# Iter 968: Loss=0.2634, Noise=0.0070
# Iter 969: Loss=0.2624, Noise=0.0070
# Iter 970: Loss=0.2887, Noise=0.0070
# Iter 971: Loss=0.2656, Noise=0.0070
# Iter 972: Loss=0.2773, Noise=0.0070
# Iter 973: Loss=0.2772, Noise=0.0070
# Iter 974: Loss=0.2808, Noise=0.0070
# Iter 975: Loss=0.3054, Noise=0.0070
# Iter 976: Loss=0.2525, Noise=0.0070
# Iter 977: Loss=0.3110, Noise=0.0070
# Iter 978: Loss=0.3211, Noise=0.0070
# Iter 979: Loss=0.2829, Noise=0.0070
# Iter 980: Loss=0.2697, Noise=0.0070
# Iter 981: Loss=0.2932, Noise=0.0070
# Iter 982: Loss=0.2821, Noise=0.0070
# Iter 983: Loss=0.2763, Noise=0.0070
# Iter 984: Loss=0.2710, Noise=0.0070
# Iter 985: Loss=0.2781, Noise=0.0070
# Iter 986: Loss=0.2916, Noise=0.0070
# Iter 987: Loss=0.2845, Noise=0.0070
# Iter 988: Loss=0.2668, Noise=0.0070
# Iter 989: Loss=0.2552, Noise=0.0070
# Iter 990: Loss=0.2619, Noise=0.0070
# Iter 991: Loss=0.2411, Noise=0.0070
# Iter 992: Loss=0.2648, Noise=0.0070
# Iter 993: Loss=0.3159, Noise=0.0070
# Iter 994: Loss=0.2393, Noise=0.0070
# Iter 995: Loss=0.2751, Noise=0.0070
# Iter 996: Loss=0.2803, Noise=0.0070
# Iter 997: Loss=0.2618, Noise=0.0070
# Iter 998: Loss=0.2509, Noise=0.0070
# Iter 999: Loss=0.2634, Noise=0.0070

# %%
# Test the model
with torch.no_grad():
    model.eval()
    model.likelihood.eval()
    output = model(test_x)
    rmse = (test_y - output.mean).pow(2).mean().sqrt().item()
    neg_log_lik = -mll(output, test_y).item()
    print('RMSE={:2.4f}, Neg Log Likelihood={:2.4f}'.format(rmse, neg_log_lik))
# Out:
# RMSE=0.8409, Neg Log Likelihood=0.1101
